# %%
import tensorflow as tf

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 20]

    return trimmed_words

def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
with open('C://kelimeler_sobiad.txt', encoding='utf-8') as f:
    text = f.read()

# %%
words = preprocess(text)

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 79271031
# Unique words: 143992

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
vocab_to_int
# Out:
# {'ve': 0,
#  'the': 1,
#  'of': 2,
#  'and': 3,
#  'in': 4,
#  'a': 5,
#  'bir': 6,
#  'bu': 7,
#  'ile': 8,
#  'olarak': 9,
#  'to': 10,
#  'için': 11,
#  'for': 12,
#  'm': 13,
#  'is': 14,
#  'de': 15,
#  'on': 16,
#  'c': 17,
#  's': 18,
#  'b': 19,
#  'en': 20,
#  'ise': 21,
#  'with': 22,
#  'daha': 23,
#  'göre': 24,
#  'da': 25,
#  'şekil': 26,
#  'elde': 27,
#  'olan': 28,
#  'yüksek': 29,
#  'by': 30,
#  'as': 31,
#  'j': 32,
#  'olduğu': 33,
#  'l': 34,
#  'p': 35,
#  'e': 36,
#  'were': 37,
#  'was': 38,
#  'are': 39,
#  'n': 40,
#  'farklı': 41,
#  'that': 42,
#  'g': 43,
#  'edilen': 44,
#  'journal': 45,
#  'h': 46,
#  'r': 47,
#  'd': 48,
#  'from': 49,
#  'ark': 50,
#  'this': 51,
#  'k': 52,
#  'gibi': 53,
#  'x': 54,
#  't': 55,
#  'önemli': 56,
#  'çok': 57,
#  'çalışmada': 58,
#  'yapılan': 59,
#  'i': 60,
#  'et': 61,
#  'arasında': 62,
#  'f': 63,
#  'be': 64,
#  'al': 65,
#  'her': 66,
#  'edilmiştir': 67,
#  'dergisi': 68,
#  'su': 69,
#  'üniversitesi': 70,
#  'at': 71,
#  'study': 72,
#  'it': 73,
#  'sahip': 74,
#  'çalışma': 75,
#  'kullanılan': 76,
#  'toplam': 77,
#  'diğer': 78,
#  'tablo': 79,
#  'y': 80,
#  'değerleri': 81,
#  'düşük': 82,
#  'yer': 83,
#  'an': 84,
#  'tespit': 85,
#  'ortalama': 86,
#  'iki': 87,
#  'ait': 88,
#  'şekilde': 89,
#  'mm': 90,
#  'üzerinde': 91,
#  'üzerine': 92,
#  'using': 93,
#  'tarafından': 94,
#  'veya': 95,
#  'çizelge': 96,
#  'model': 97,
#  'bitki': 98,
#  'used': 99,
#  'araştırma': 100,
#  'sonra': 101,
#  'belirlenmiştir': 102,
#  'fazla': 103,
#  '<semicolon>': 104,
#  'analysis': 105,
#  'bazı': 106,
#  'no': 107,
#  'o': 108,
#  'oranı': 109,
#  'which': 110,
#  'alan': 111,
#  'büyük': 112,
#  'kullanılarak': 113,
#  'research': 114,
#  'different': 115,
#  'olması': 116,
#  'sayısı': 117,
#  'bağlı': 118,
#  'değeri': 119,
#  'ayrıca': 120,
#  'fakültesi': 121,
#  'toprak': 122,
#  'aynı': 123,
#  'üretim': 124,
#  'olup': 125,
#  'cm': 126,
#  'vd': 127,
#  'kontrol': 128,
#  'mevcut': 129,
#  'enerji': 130,
#  'v': 131,
#  'have': 132,
#  'ortaya': 133,
#  'uygun': 134,
#  'can': 135,
#  'science': 136,
#  'test': 137,
#  'kadar': 138,
#  'bilimleri': 139,
#  'özellikleri': 140,
#  'tüm': 141,
#  'fen': 142,
#  'birlikte': 143,
#  'results': 144,
#  'etkisi': 145,
#  'has': 146,
#  'türkiye': 147,
#  'hem': 148,
#  'method': 149,
#  'arasındaki': 150,
#  'water': 151,
#  'engineering': 152,
#  'university': 153,
#  'system': 154,
#  'analizi': 155,
#  'figure': 156,
#  'turkey': 157,
#  'görülmektedir': 158,
#  'bulunan': 159,
#  'effect': 160,
#  'ilgili': 161,
#  'çalışmanın': 162,
#  'az': 163,
#  'genel': 164,
#  'data': 165,
#  'between': 166,
#  'ancak': 167,
#  'food': 168,
#  'verilmiştir': 169,
#  'üzere': 170,
#  'veri': 171,
#  'values': 172,
#  'son': 173,
#  'tarım': 174,
#  'table': 175,
#  'sonuçlar': 176,
#  'açısından': 177,
#  'kullanılmıştır': 178,
#  'yeni': 179,
#  'these': 180,
#  'been': 181,
#  'adet': 182,
#  'orman': 183,
#  'sci': 184,
#  'z': 185,
#  'iyi': 186,
#  'yöntemi': 187,
#  'özellikle': 188,
#  'yapılmıştır': 189,
#  'plant': 190,
#  'analiz': 191,
#  'tarihi': 192,
#  'sonucunda': 193,
#  'w': 194,
#  'properties': 195,
#  'ankara': 196,
#  'ya': 197,
#  'effects': 198,
#  'energy': 199,
#  'or': 200,
#  'u': 201,
#  'international': 202,
#  'ilk': 203,
#  'new': 204,
#  'özet': 205,
#  'kg': 206,
#  'production': 207,
#  'not': 208,
#  'doğal': 209,
#  'içerisinde': 210,
#  'kabul': 211,
#  'olduğunu': 212,
#  'enstitüsü': 213,
#  'ph': 214,
#  'pp': 215,
#  'meydana': 216,
#  'belirlenmesi': 217,
#  'also': 218,
#  'control': 219,
#  'gün': 220,
#  'some': 221,
#  'zaman': 222,
#  'yüzey': 223,
#  'sıcaklık': 224,
#  'asit': 225,
#  'değildir': 226,
#  'ifade': 227,
#  'soil': 228,
#  'mg': 229,
#  'miktarı': 230,
#  'their': 231,
#  'neden': 232,
#  'temel': 233,
#  'obtained': 234,
#  'amacıyla': 235,
#  'methods': 236,
#  'tek': 237,
#  'üç': 238,
#  'all': 239,
#  'yılında': 240,
#  'göstermektedir': 241,
#  'oluşan': 242,
#  'time': 243,
#  'verim': 244,
#  'birçok': 245,
#  'sonuç': 246,
#  'bilgisi': 247,
#  'organik': 248,
#  'sonuçları': 249,
#  'alt': 250,
#  'sırasıyla': 251,
#  'technology': 252,
#  'durum': 253,
#  'protein': 254,
#  'ab': 255,
#  'based': 256,
#  'alanı': 257,
#  'kimyasal': 258,
#  'madde': 259,
#  'number': 260,
#  'systems': 261,
#  'yıl': 262,
#  'oldukça': 263,
#  'yaklaşık': 264,
#  'karşı': 265,
#  'other': 266,
#  'orta': 267,
#  'total': 268,
#  'gelen': 269,
#  'quality': 270,
#  'çeşitli': 271,
#  'bulunmuştur': 272,
#  'altında': 273,
#  'we': 274,
#  'gıda': 275,
#  'design': 276,
#  'species': 277,
#  'meyve': 278,
#  'high': 279,
#  'determined': 280,
#  'samples': 281,
#  'içinde': 282,
#  'olmak': 283,
#  'sonucu': 284,
#  'küçük': 285,
#  'alınan': 286,
#  'kuru': 287,
#  'ziraat': 288,
#  'doğru': 289,
#  'its': 290,
#  'applied': 291,
#  'ana': 292,
#  'uygulama': 293,
#  'bölümü': 294,
#  'materials': 295,
#  'use': 296,
#  'bakımından': 297,
#  'etkileri': 298,
#  'sistemi': 299,
#  'according': 300,
#  'verimi': 301,
#  'üretimi': 302,
#  'studies': 303,
#  'bilgi': 304,
#  'yönelik': 305,
#  'hava': 306,
#  'vol': 307,
#  'value': 308,
#  'ürün': 309,
#  'tane': 310,
#  'dolayı': 311,
#  'faculty': 312,
#  'etkili': 313,
#  'içeren': 314,
#  'performance': 315,
#  'uzun': 316,
#  'yöntem': 317,
#  'such': 318,
#  'temperature': 319,
#  'metal': 320,
#  'eğitim': 321,
#  'yağ': 322,
#  'çalışmalar': 323,
#  'görülmüştür': 324,
#  'process': 325,
#  'çevre': 326,
#  'one': 327,
#  'than': 328,
#  'two': 329,
#  'benzer': 330,
#  'örnek': 331,
#  'sulama': 332,
#  'sayı': 333,
#  'found': 334,
#  'nedeniyle': 335,
#  'i̇': 336,
#  'parameters': 337,
#  'olmayan': 338,
#  'bunun': 339,
#  'süt': 340,
#  'area': 341,
#  'sadece': 342,
#  'değer': 343,
#  'edilmiş': 344,
#  'ml': 345,
#  'during': 346,
#  'tarımsal': 347,
#  'verilen': 348,
#  'te': 349,
#  'ekim': 350,
#  'kaynak': 351,
#  'kullanımı': 352,
#  'uygulanan': 353,
#  'surface': 354,
#  'nedenle': 355,
#  'doi': 356,
#  'acid': 357,
#  'i̇stanbul': 358,
#  'etki': 359,
#  'buna': 360,
#  'ekonomik': 361,
#  'bilim': 362,
#  'there': 363,
#  'th': 364,
#  'conditions': 365,
#  'yapı': 366,
#  'yakın': 367,
#  'dikkate': 368,
#  'under': 369,
#  'iş': 370,
#  'each': 371,
#  'important': 372,
#  'bulunmaktadır': 373,
#  'after': 374,
#  'süresi': 375,
#  'yield': 376,
#  'artış': 377,
#  'more': 378,
#  'deneysel': 379,
#  'most': 380,
#  'kalite': 381,
#  'anahtar': 382,
#  'yaprak': 383,
#  'mühendislik': 384,
#  'modeli': 385,
#  'incelendiğinde': 386,
#  'değerler': 387,
#  'özel': 388,
#  'etmektedir': 389,
#  'kullanım': 390,
#  'üzerindeki': 391,
#  'yol': 392,
#  'olmuştur': 393,
#  'sistem': 394,
#  'üretilen': 395,
#  'applications': 396,
#  'türkiyede': 397,
#  'malzeme': 398,
#  'veriler': 399,
#  'management': 400,
#  'yıllık': 401,
#  'fiziksel': 402,
#  'ii': 403,
#  'saat': 404,
#  'risk': 405,
#  'tezi': 406,
#  'power': 407,
#  'application': 408,
#  'growth': 409,
#  'ısı': 410,
#  'güç': 411,
#  'önem': 412,
#  'agricultural': 413,
#  'teknik': 414,
#  'development': 415,
#  'eden': 416,
#  'level': 417,
#  'edilmesi': 418,
#  'maksimum': 419,
#  'they': 420,
#  'when': 421,
#  'ağırlığı': 422,
#  'tahmin': 423,
#  'standart': 424,
#  'kullanılmaktadır': 425,
#  'kelimeler': 426,
#  'olmaktadır': 427,
#  'yaygın': 428,
#  'önce': 429,
#  'activity': 430,
#  'into': 431,
#  'sciences': 432,
#  'tür': 433,
#  'şeklinde': 434,
#  'sıra': 435,
#  'tercih': 436,
#  'natural': 437,
#  'first': 438,
#  'content': 439,
#  'alınmıştır': 440,
#  'değerlerinin': 441,
#  'plants': 442,
#  'structure': 443,
#  'yaş': 444,
#  'deney': 445,
#  'boyunca': 446,
#  'istatistiksel': 447,
#  'alınarak': 448,
#  'ön': 449,
#  'giriş': 450,
#  'cilt': 451,
#  'hızı': 452,
#  'problem': 453,
#  'environmental': 454,
#  'elektrik': 455,
#  'turkish': 456,
#  'yeşil': 457,
#  'incelenmiştir': 458,
#  'basınç': 459,
#  'suyu': 460,
#  'tasarım': 461,
#  'derg': 462,
#  'ikinci': 463,
#  'oranında': 464,
#  'durumu': 465,
#  'order': 466,
#  'information': 467,
#  'işlemi': 468,
#  'sahiptir': 469,
#  'anadolu': 470,
#  'rate': 471,
#  'sosyal': 472,
#  'co': 473,
#  'hesaplanmıştır': 474,
#  'chemical': 475,
#  'ilişkin': 476,
#  'deneme': 477,
#  'hızlı': 478,
#  'characteristics': 479,
#  'açık': 480,
#  'genellikle': 481,
#  'abstract': 482,
#  'material': 483,
#  'besin': 484,
#  'then': 485,
#  'karar': 486,
#  'yem': 487,
#  'part': 488,
#  'q': 489,
#  'edilmektedir': 490,
#  'üst': 491,
#  'if': 492,
#  'mühendisliği': 493,
#  'mekanik': 494,
#  'teknoloji': 495,
#  'gerekli': 496,
#  'çalışmalarda': 497,
#  'significant': 498,
#  'burada': 499,
#  'may': 500,
#  'normal': 501,
#  'gerçekleştirilmiştir': 502,
#  'kısa': 503,
#  'ne': 504,
#  'region': 505,
#  'arazi': 506,
#  'geri': 507,
#  'anonim': 508,
#  'herhangi': 509,
#  'renk': 510,
#  'türk': 511,
#  'sabit': 512,
#  'ağırlık': 513,
#  'göz': 514,
#  'distribution': 515,
#  'respectively': 516,
#  'ms': 517,
#  'given': 518,
#  'gerekmektedir': 519,
#  'result': 520,
#  'erişim': 521,
#  'lisans': 522,
#  'kapsamında': 523,
#  'tam': 524,
#  'out': 525,
#  'type': 526,
#  'kök': 527,
#  'where': 528,
#  'van': 529,
#  'ayrı': 530,
#  'experimental': 531,
#  'article': 532,
#  'group': 533,
#  'field': 534,
#  'observed': 535,
#  'söz': 536,
#  'insan': 537,
#  'due': 538,
#  'özelliklerinin': 539,
#  'biri': 540,
#  'ppm': 541,
#  'materyal': 542,
#  'dış': 543,
#  'oil': 544,
#  'sırasında': 545,
#  'yapısı': 546,
#  'yeterli': 547,
#  'both': 548,
#  'arası': 549,
#  'nem': 550,
#  'olumsuz': 551,
#  'artan': 552,
#  'keywords': 553,
#  'içeriği': 554,
#  'ölçüm': 555,
#  'evaluation': 556,
#  'increase': 557,
#  'göstermiştir': 558,
#  'araştırmada': 559,
#  'fark': 560,
#  'belirlenen': 561,
#  'zamanda': 562,
#  'levels': 563,
#  'weight': 564,
#  'review': 565,
#  'tipi': 566,
#  'testi': 567,
#  'ele': 568,
#  'gösterilmiştir': 569,
#  'gazi': 570,
#  'optimum': 571,
#  'yıllarda': 572,
#  'kesme': 573,
#  'sp': 574,
#  'sonrası': 575,
#  'değişim': 576,
#  'birim': 577,
#  'hücre': 578,
#  'kaynaklar': 579,
#  'heat': 580,
#  'iç': 581,
#  'determination': 582,
#  'günlük': 583,
#  'yapılmış': 584,
#  'oranları': 585,
#  'etmek': 586,
#  'işlem': 587,
#  'while': 588,
#  'performans': 589,
#  'bölgesinde': 590,
#  'değişimi': 591,
#  'konusu': 592,
#  'solution': 593,
#  'grup': 594,
#  'ö': 595,
#  'ü': 596,
#  'yerine': 597,
#  'var': 598,
#  'hata': 599,
#  'yöntemleri': 600,
#  'hayvan': 601,
#  'bitkileri': 602,
#  'ürünleri': 603,
#  'verileri': 604,
#  'atık': 605,
#  'case': 606,
#  'geleneksel': 607,
#  'higher': 608,
#  'önerilen': 609,
#  'buğday': 610,
#  'ca': 611,
#  'km': 612,
#  'bölgesi': 613,
#  'areas': 614,
#  'gösteren': 615,
#  'vb': 616,
#  'olmadığı': 617,
#  'but': 618,
#  'li': 619,
#  'etkin': 620,
#  'çalışmaları': 621,
#  'bulgular': 622,
#  'low': 623,
#  'fak': 624,
#  'yük': 625,
#  'iklim': 626,
#  'dolayısıyla': 627,
#  'three': 628,
#  'increased': 629,
#  'ülkemizde': 630,
#  'çelik': 631,
#  'architecture': 632,
#  'den': 633,
#  'güneş': 634,
#  'düzeyde': 635,
#  'about': 636,
#  'si': 637,
#  'gerçek': 638,
#  'aktif': 639,
#  'environment': 640,
#  'tohum': 641,
#  'geniş': 642,
#  'çözüm': 643,
#  'cd': 644,
#  'compared': 645,
#  'uygulaması': 646,
#  'kullanılması': 647,
#  'stress': 648,
#  'products': 649,
#  'however': 650,
#  'agriculture': 651,
#  'ha': 652,
#  'farklılık': 653,
#  'almaktadır': 654,
#  'iken': 655,
#  'özellikler': 656,
#  'treatment': 657,
#  'bc': 658,
#  'will': 659,
#  'ratio': 660,
#  'devam': 661,
#  'koruma': 662,
#  'parametreleri': 663,
#  'ma': 664,
#  'çıkan': 665,
#  'birinci': 666,
#  'average': 667,
#  'yılı': 668,
#  'boyu': 669,
#  'factors': 670,
#  'yine': 671,
#  'saptanmıştır': 672,
#  'grubu': 673,
#  'değerlendirilmesi': 674,
#  'minimum': 675,
#  'edilir': 676,
#  'wang': 677,
#  'rağmen': 678,
#  'konusunda': 679,
#  'bölge': 680,
#  'biyolojik': 681,
#  'türü': 682,
#  'katsayısı': 683,
#  'katkı': 684,
#  'terms': 685,
#  'bütün': 686,
#  'anlamlı': 687,
#  'thermal': 688,
#  'kullanarak': 689,
#  'alanda': 690,
#  'sıcaklığı': 691,
#  'approach': 692,
#  'ağaç': 693,
#  'yoğun': 694,
#  'süre': 695,
#  'belirli': 696,
#  'durumunda': 697,
#  'alanında': 698,
#  'cde': 699,
#  'koşullarında': 700,
#  'amacı': 701,
#  'hale': 702,
#  'sistemleri': 703,
#  'potential': 704,
#  'durumda': 705,
#  'depolama': 706,
#  'doğu': 707,
#  'aşağıdaki': 708,
#  'üretiminde': 709,
#  'mean': 710,
#  'deprem': 711,
#  'oc': 712,
#  'univ': 713,
#  'sağlık': 714,
#  'görüldüğü': 715,
#  'vardır': 716,
#  'conference': 717,
#  'yapılması': 718,
#  'health': 719,
#  'etkisinin': 720,
#  'dünya': 721,
#  'tip': 722,
#  'aa': 723,
#  'algorithm': 724,
#  'böylece': 725,
#  'önemlidir': 726,
#  'calculated': 727,
#  'sayıda': 728,
#  'fakat': 729,
#  'ilave': 730,
#  'motor': 731,
#  'kalitesi': 732,
#  'investigated': 733,
#  'volume': 734,
#  'değerlendirme': 735,
#  'uygulamaları': 736,
#  'tabanlı': 737,
#  'sistemin': 738,
#  'ili': 739,
#  'pozitif': 740,
#  'alanları': 741,
#  'demir': 742,
#  'models': 743,
#  'yabancı': 744,
#  'human': 745,
#  'determine': 746,
#  'analizleri': 747,
#  'ege': 748,
#  'transfer': 749,
#  'değerinin': 750,
#  'kaya': 751,
#  'sonunda': 752,
#  'function': 753,
#  'günümüzde': 754,
#  'çevresel': 755,
#  'karbon': 756,
#  'addition': 757,
#  'same': 758,
#  'change': 759,
#  'başına': 760,
#  'so': 761,
#  'hakkında': 762,
#  'doğrusal': 763,
#  'literatürde': 764,
#  'ilişki': 765,
#  'çekme': 766,
#  'many': 767,
#  'nm': 768,
#  'azot': 769,
#  'belirlemek': 770,
#  'various': 771,
#  'boyutlu': 772,
#  'hasat': 773,
#  'merkez': 774,
#  'alternatif': 775,
#  'mgl': 776,
#  'genetik': 777,
#  'dağılımı': 778,
#  'only': 779,
#  'kat': 780,
#  'flow': 781,
#  'should': 782,
#  'changes': 783,
#  'sürekli': 784,
#  'size': 785,
#  'akım': 786,
#  'sample': 787,
#  'yanında': 788,
#  'organic': 789,
#  'yanı': 790,
#  'cell': 791,
#  'oranda': 792,
#  'bitkilerin': 793,
#  'çalışmalarında': 794,
#  'gaz': 795,
#  'years': 796,
#  'ieee': 797,
#  'kent': 798,
#  'yerel': 799,
#  'programı': 800,
#  'başka': 801,
#  'fe': 802,
#  'kendi': 803,
#  'kalan': 804,
#  'geliştirilen': 805,
#  'örneğin': 806,
#  'kaynağı': 807,
#  'bitkisel': 808,
#  'shown': 809,
#  'comparison': 810,
#  'olumlu': 811,
#  'bulunduğu': 812,
#  'doğrudan': 813,
#  'through': 814,
#  'uzunluğu': 815,
#  'sayısal': 816,
#  'edilebilir': 817,
#  'ihtiyaç': 818,
#  'üzerinden': 819,
#  'issn': 820,
#  'very': 821,
#  'ek': 822,
#  'dna': 823,
#  'ısıl': 824,
#  'problems': 825,
#  'set': 826,
#  'yapay': 827,
#  'i̇zmir': 828,
#  'zn': 829,
#  'akış': 830,
#  'müdürlüğü': 831,
#  'form': 832,
#  'european': 833,
#  'cu': 834,
#  'density': 835,
#  'usa': 836,
#  'had': 837,
#  'öz': 838,
#  'çıkış': 839,
#  'accepted': 840,
#  'bilimsel': 841,
#  'işleme': 842,
#  'dört': 843,
#  'forest': 844,
#  'fuzzy': 845,
#  'period': 846,
#  'ot': 847,
#  'hız': 848,
#  'physical': 849,
#  'air': 850,
#  'akdeniz': 851,
#  'frekans': 852,
#  'tl': 853,
#  'beton': 854,
#  'ed': 855,
#  'miktarının': 856,
#  'equation': 857,
#  'oranının': 858,
#  'türleri': 859,
#  'ki': 860,
#  'among': 861,
#  'katı': 862,
#  'mechanical': 863,
#  'oldukları': 864,
#  'gelir': 865,
#  'tuz': 866,
#  'uçucu': 867,
#  'carried': 868,
#  'groups': 869,
#  'therefore': 870,
#  'ham': 871,
#  'paper': 872,
#  'received': 873,
#  'mn': 874,
#  'yumurta': 875,
#  'concentration': 876,
#  'mısır': 877,
#  'edilerek': 878,
#  'current': 879,
#  'efficiency': 880,
#  'kompozit': 881,
#  'network': 882,
#  'sorumlu': 883,
#  'highest': 884,
#  'yardımıyla': 885,
#  'işletme': 886,
#  'proje': 887,
#  'tarla': 888,
#  'bununla': 889,
#  'world': 890,
#  'oluşturulan': 891,
#  'nolu': 892,
#  'main': 893,
#  'bilgisayar': 894,
#  'element': 895,
#  'fiber': 896,
#  'our': 897,
#  'yok': 898,
#  'zhang': 899,
#  'gereken': 900,
#  'processing': 901,
#  'regresyon': 902,
#  'resistance': 903,
#  'sebep': 904,
#  'department': 905,
#  'within': 906,
#  'hazırlanan': 907,
#  'amount': 908,
#  'hesaplanan': 909,
#  'ton': 910,
#  'verilerin': 911,
#  'length': 912,
#  'geliş': 913,
#  'zemin': 914,
#  'eş': 915,
#  'kültür': 916,
#  'antioxidant': 917,
#  'aralığında': 918,
#  'seed': 919,
#  'yazar': 920,
#  'fruit': 921,
#  'developed': 922,
#  'mineral': 923,
#  'performed': 924,
#  'strength': 925,
#  'çeşit': 926,
#  'min': 927,
#  'optimization': 928,
#  'investigation': 929,
#  'kaynaklı': 930,
#  'mümkün': 931,
#  'yapısal': 932,
#  'related': 933,
#  'denklem': 934,
#  'sayısının': 935,
#  'anket': 936,
#  'fonksiyonu': 937,
#  'kgda': 938,
#  'büyüme': 939,
#  'standard': 940,
#  'mayıs': 941,
#  'showed': 942,
#  'düzeyinde': 943,
#  'bölgede': 944,
#  'merkezi': 945,
#  'author': 946,
#  'produced': 947,
#  'kentsel': 948,
#  'ağır': 949,
#  'because': 950,
#  'gözlenmiştir': 951,
#  'kurutma': 952,
#  'yağış': 953,
#  'araştırmalar': 954,
#  'maruz': 955,
#  'work': 956,
#  'gübre': 957,
#  'gelmektedir': 958,
#  'press': 959,
#  'enerjisi': 960,
#  'yönde': 961,
#  'ortalaması': 962,
#  'alanlarda': 963,
#  'sisteminin': 964,
#  'ağ': 965,
#  'iii': 966,
#  'yani': 967,
#  'yaşam': 968,
#  'ulusal': 969,
#  'hareket': 970,
#  'increasing': 971,
#  'uygulanmıştır': 972,
#  'yöntemler': 973,
#  'karadeniz': 974,
#  'antioksidan': 975,
#  'örneği': 976,
#  'seen': 977,
#  'yapan': 978,
#  'point': 979,
#  'ekolojik': 980,
#  'animal': 981,
#  'milk': 982,
#  'ss': 983,
#  'made': 984,
#  'tasarımı': 985,
#  'etkileyen': 986,
#  'serbest': 987,
#  'lif': 988,
#  'düşünülmektedir': 989,
#  'ts': 990,
#  'araç': 991,
#  'structures': 992,
#  'olmasına': 993,
#  'proposed': 994,
#  'kaplama': 995,
#  'geçen': 996,
#  'oluşmaktadır': 997,
#  'amaçla': 998,
#  'oluşturmaktadır': 999,
#  ...}

# %%
import numpy as np
import tensorflow as tf
from collections import Counter
import random

threshold = 1e-6
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 15378985

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)
    
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
tf.compat.v1.disable_eager_execution()
with tf.Graph().as_default() as train_graph:
    inputs = tf.compat.v1.placeholder(tf.int32, [None], name='inputs')
    labels = tf.compat.v1.placeholder(tf.int32, [None, None], name='labels')

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random.uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.compat.v1.train.AdamOptimizer().minimize(cost)

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.math.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# !mkdir checkpoints

# %%
import time
epochs = 15
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.compat.v1.train.Saver()

with tf.compat.v1.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.compat.v1.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
        embed_mat = sess.run(normalized_embedding)
    
        with open('C://checkpoints/embedding_sobiad.txt', 'w') as file_:
            for i in range(n_vocab):
                embd = embed_mat[i, :]
                wrd = int_to_vocab[i]
                file_.write('%s %s\n' % (wrd, ' '.join(map(str, embd))))
# Out:
# Streaming output truncated to the last 5000 lines.
# Nearest to sınıf: cta, içerikleri, tags, mitteleuropa, hendek, doiklujes, ilginçlik, elementleri,
# Epoch 3/15 Iteration: 38100 Avg. Training loss: 3.6044 0.0276 sec/batch
# Epoch 3/15 Iteration: 38200 Avg. Training loss: 3.6797 0.0254 sec/batch
# Epoch 3/15 Iteration: 38300 Avg. Training loss: 3.3450 0.0254 sec/batch
# Epoch 3/15 Iteration: 38400 Avg. Training loss: 3.1734 0.0253 sec/batch
# Epoch 3/15 Iteration: 38500 Avg. Training loss: 3.2293 0.0257 sec/batch
# Epoch 3/15 Iteration: 38600 Avg. Training loss: 3.3245 0.0254 sec/batch
# Epoch 3/15 Iteration: 38700 Avg. Training loss: 3.5781 0.0254 sec/batch
# Epoch 3/15 Iteration: 38800 Avg. Training loss: 3.6361 0.0253 sec/batch
# Epoch 3/15 Iteration: 38900 Avg. Training loss: 3.5322 0.0253 sec/batch
# Epoch 3/15 Iteration: 39000 Avg. Training loss: 3.6118 0.0253 sec/batch
# Nearest to used: was, tmin, folks, textiles, toksikoloji, as, package, cmr,
# Nearest to and: of, by, the, in, is, with, for, on,
# Nearest to göre: toplam, ise, elde, ve, değerleri, bu, edilen, bir,
# Nearest to f: r, kk, jt, phytogeographical, b, ultra, marthaziran, if,
# Nearest to su: suyu, sulama, nehrinde, alnmfltr, yönetmeliğine, artezyen, infante, koagülasyon,
# Nearest to as: in, have, the, and, loaf, different, that, frouz,
# Nearest to daha: bu, ve, olarak, sahip, ise, yüksek, benzer, ile,
# Nearest to on: and, effect, wires, were, of, i̇skilip, geotextiles, bramley,
# Nearest to görüntü: görüntünün, ıslah, cto, kameranın, naf, görüntüde, bilgisayarla, sayede,
# Nearest to assessment: şefliklerinde, pestalozzae, cephenin, i̇mmunohistokimyasal, riggio, organically, prevent, yree,
# Nearest to azalma: artışın, küçükken, yüküne, yüksek, cocopeat, etkisinin, gerçekleşmiştir, kifli,
# Nearest to etkisini: ve, nedeni, uygulanan, bileflenlerden, kullanmışlardır, belirlenmifl, salisilaldehit, jelleflme,
# Nearest to olur: çökük, manson, ispatı, yelpazeye, sebep, kılavuzlu, eğer, fosfin,
# Nearest to activities: study, moc, tangüler, nötre, cpgly, paydaşların, kromatit, patojenleri,
# Nearest to yoğunluğu: mıknatısın, gevrekliği, editörüarea, şekilden, tarsusun, strainlerin, opposite, konumunda,
# Nearest to sınıf: cta, içerikleri, mitteleuropa, hendek, elementleri, tags, doiklujes, yayınlarından,
# Epoch 3/15 Iteration: 39100 Avg. Training loss: 3.4533 0.0278 sec/batch
# Epoch 3/15 Iteration: 39200 Avg. Training loss: 3.5384 0.0254 sec/batch
# Epoch 3/15 Iteration: 39300 Avg. Training loss: 3.4840 0.0254 sec/batch
# Epoch 3/15 Iteration: 39400 Avg. Training loss: 3.6724 0.0253 sec/batch
# Epoch 3/15 Iteration: 39500 Avg. Training loss: 3.7315 0.0253 sec/batch
# Epoch 3/15 Iteration: 39600 Avg. Training loss: 3.6945 0.0254 sec/batch
# Epoch 3/15 Iteration: 39700 Avg. Training loss: 3.8251 0.0255 sec/batch
# Epoch 3/15 Iteration: 39800 Avg. Training loss: 3.7646 0.0254 sec/batch
# Epoch 3/15 Iteration: 39900 Avg. Training loss: 3.7647 0.0255 sec/batch
# Epoch 3/15 Iteration: 40000 Avg. Training loss: 3.7732 0.0254 sec/batch
# Nearest to used: was, folks, tmin, textiles, cmr, uygunsuzluk, toksikoloji, statistical,
# Nearest to and: of, by, the, in, with, on, for, is,
# Nearest to göre: toplam, ise, elde, tablo, değerleri, oranı, sonuçları, değer,
# Nearest to f: r, babanın, kk, açısındaki, olarakbelirlenmiştir, marthaziran, b, dh,
# Nearest to su: suyu, sulama, nehrinde, yönetmeliğine, artezyen, dereleri, infante, alnmfltr,
# Nearest to as: have, in, and, the, different, even, frouz, socks,
# Nearest to daha: bu, iyi, sahip, ile, yüksek, benzer, ise, ve,
# Nearest to on: and, effect, wires, were, of, geotextiles, bramley, i̇skilip,
# Nearest to görüntü: görüntünün, ıslah, kameranın, cto, sayede, görüntüde, naf, pikseller,
# Nearest to assessment: cephenin, yree, şefliklerinde, i̇mmunohistokimyasal, pestalozzae, prevent, genelmüdürlüü, mandibulası,
# Nearest to azalma: artışın, küçükken, yüküne, gerçekleşmiştir, cocopeat, mises, yüksek, etkisinin,
# Nearest to etkisini: ve, nedeni, uygulanan, kullanmışlardır, salisilaldehit, araştırılmıştır, yayınıma, esasli,
# Nearest to olur: çökük, ispatı, eğer, manson, kılavuzlu, yelpazeye, ifadeyi, iif,
# Nearest to activities: moc, tangüler, paydaşların, kromatit, study, cpgly, nötre, patojenleri,
# Nearest to yoğunluğu: gevrekliği, soğurmanın, mıknatısın, strainlerin, şekilden, editörüarea, konumunda, opposite,
# Nearest to sınıf: tags, mitteleuropa, cta, dersine, doiklujes, i̇lköğretimde, elementleri, yayınlarından,
# Epoch 3/15 Iteration: 40100 Avg. Training loss: 3.7558 0.0276 sec/batch
# Epoch 3/15 Iteration: 40200 Avg. Training loss: 3.7277 0.0255 sec/batch
# Epoch 3/15 Iteration: 40300 Avg. Training loss: 3.7071 0.0257 sec/batch
# Epoch 3/15 Iteration: 40400 Avg. Training loss: 3.7696 0.0254 sec/batch
# Epoch 3/15 Iteration: 40500 Avg. Training loss: 3.6957 0.0256 sec/batch
# Epoch 3/15 Iteration: 40600 Avg. Training loss: 3.6929 0.0254 sec/batch
# Epoch 3/15 Iteration: 40700 Avg. Training loss: 3.7852 0.0254 sec/batch
# Epoch 3/15 Iteration: 40800 Avg. Training loss: 3.6469 0.0253 sec/batch
# Epoch 3/15 Iteration: 40900 Avg. Training loss: 3.6502 0.0255 sec/batch
# Epoch 3/15 Iteration: 41000 Avg. Training loss: 3.6074 0.0253 sec/batch
# Nearest to used: was, folks, four, tmin, textiles, cmr, toksikoloji, as,
# Nearest to and: of, by, the, in, on, with, for, is,
# Nearest to göre: ise, tablo, toplam, elde, oranı, ve, değerleri, edilmiştir,
# Nearest to f: r, b, açısındaki, dh, enleri, babanın, phytogeographical, kk,
# Nearest to su: suyu, sulama, nehrinde, yönetmeliğine, artezyen, dereleri, infante, bektaş,
# Nearest to as: have, in, the, and, different, with, that, wereobserved,
# Nearest to daha: ve, sahip, yüksek, bu, ile, olarak, olduğu, farklı,
# Nearest to on: and, effect, wires, of, were, geotextiles, bramley, was,
# Nearest to görüntü: görüntünün, ıslah, kameranın, sayede, cto, naf, görüntüde, asiltürk,
# Nearest to assessment: pestalozzae, i̇mmunohistokimyasal, cephenin, şefliklerinde, yree, mandibulası, organically, aliğdır,
# Nearest to azalma: artışın, gerçekleşmiştir, cocopeat, küçükken, yüküne, mises, etkisinin, ortaklıkları,
# Nearest to etkisini: uygulanan, ve, kullanmışlardır, nedeni, çalışmada, araştırılmıştır, etkisinin, ilerleme,
# Nearest to olur: çökük, ispatı, manson, eğer, kılavuzlu, yelpazeye, epidermise, iif,
# Nearest to activities: moc, tangüler, kromatit, study, paydaşların, biosynthesis, patojenleri, cpgly,
# Nearest to yoğunluğu: editörüarea, gevrekliği, strainlerin, şekilden, konumunda, tarsusun, soğurmanın, mıknatısın,
# Nearest to sınıf: cta, içerikleri, elementleri, yayınlarından, doiklujes, tags, mitteleuropa, i̇lköğretimde,
# Epoch 3/15 Iteration: 41100 Avg. Training loss: 3.6974 0.0277 sec/batch
# Epoch 3/15 Iteration: 41200 Avg. Training loss: 3.7149 0.0254 sec/batch
# Epoch 3/15 Iteration: 41300 Avg. Training loss: 3.6314 0.0253 sec/batch
# Epoch 3/15 Iteration: 41400 Avg. Training loss: 3.6916 0.0254 sec/batch
# Epoch 3/15 Iteration: 41500 Avg. Training loss: 3.7044 0.0255 sec/batch
# Epoch 3/15 Iteration: 41600 Avg. Training loss: 3.6062 0.0253 sec/batch
# Epoch 3/15 Iteration: 41700 Avg. Training loss: 3.5998 0.0255 sec/batch
# Epoch 3/15 Iteration: 41800 Avg. Training loss: 3.6059 0.0254 sec/batch
# Epoch 3/15 Iteration: 41900 Avg. Training loss: 3.6787 0.0253 sec/batch
# Epoch 3/15 Iteration: 42000 Avg. Training loss: 3.8439 0.0253 sec/batch
# Nearest to used: toksikoloji, folks, was, cmr, textiles, economical, tmin, seleksiyonunda,
# Nearest to and: of, by, the, is, in, for, on, with,
# Nearest to göre: tablo, toplam, ise, değerleri, oranı, sonuçları, elde, çalışmada,
# Nearest to f: r, if, a, dh, b, olarakbelirlenmiştir, phytogeographical, enleri,
# Nearest to su: suyu, sulama, yönetmeliğine, nehrinde, dereleri, infante, artezyen, bektaş,
# Nearest to as: have, in, and, the, different, wereobserved, terms, yücesan,
# Nearest to daha: sahip, ve, yüksek, ile, olduğu, bu, düşük, iyi,
# Nearest to on: and, effect, wires, geotextiles, dmd, admitting, melodia, y,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, ıslah, cto, asiltürk, sayede, pikseller,
# Nearest to assessment: pestalozzae, i̇mmunohistokimyasal, şefliklerinde, aliğdır, organically, yree, cephenin, mandibulası,
# Nearest to azalma: artışın, cocopeat, yüküne, gerçekleşmiştir, küçükken, ortaklıkları, mises, rolünün,
# Nearest to etkisini: uygulanan, kullanmışlardır, nedeni, ve, etkilerini, yayınıma, araştırılmıştır, etkisinin,
# Nearest to olur: çökük, ispatı, manson, yelpazeye, fosfin, kılavuzlu, ifadeyi, epidermise,
# Nearest to activities: moc, kromatit, paydaşların, tangüler, study, nötre, biosynthesis, patojenleri,
# Nearest to yoğunluğu: editörüarea, konumunda, gevrekliği, strainlerin, soğurmanın, tarsusun, mıknatısın, şekilden,
# Nearest to sınıf: cta, yayınlarından, i̇lköğretimde, tags, doiklujes, elementleri, dersine, öğrenci,
# Epoch 3/15 Iteration: 42100 Avg. Training loss: 3.8230 0.0277 sec/batch
# Epoch 3/15 Iteration: 42200 Avg. Training loss: 3.7976 0.0255 sec/batch
# Epoch 3/15 Iteration: 42300 Avg. Training loss: 3.7532 0.0255 sec/batch
# Epoch 3/15 Iteration: 42400 Avg. Training loss: 3.7177 0.0254 sec/batch
# Epoch 3/15 Iteration: 42500 Avg. Training loss: 3.6993 0.0254 sec/batch
# Epoch 3/15 Iteration: 42600 Avg. Training loss: 3.7033 0.0254 sec/batch
# Epoch 3/15 Iteration: 42700 Avg. Training loss: 3.6014 0.0255 sec/batch
# Epoch 3/15 Iteration: 42800 Avg. Training loss: 3.6229 0.0253 sec/batch
# Epoch 3/15 Iteration: 42900 Avg. Training loss: 3.6312 0.0253 sec/batch
# Epoch 3/15 Iteration: 43000 Avg. Training loss: 3.5428 0.0253 sec/batch
# Nearest to used: toksikoloji, was, cmr, folks, tmin, textiles, four, statistical,
# Nearest to and: of, the, in, by, is, on, with, for,
# Nearest to göre: tablo, toplam, ise, değerleri, sonuçları, oranı, çalışmada, edilmiştir,
# Nearest to f: r, if, b, dh, a, kk, babanın, olarakbelirlenmiştir,
# Nearest to su: suyu, sulama, nehrinde, yönetmeliğine, infante, dereleri, suyun, artezyen,
# Nearest to as: in, have, the, and, different, frouz, with, that,
# Nearest to daha: yüksek, sahip, benzer, iyi, olmuştur, düşük, arasında, dikimlerde,
# Nearest to on: and, effect, p, wires, not, dmd, geotextiles, were,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, pikseller, cto, ıslah, sayede, asiltürk,
# Nearest to assessment: i̇mmunohistokimyasal, pestalozzae, yree, aliğdır, şefliklerinde, organically, definitely, prevent,
# Nearest to azalma: artışın, küçükken, ortaklıkları, rolünün, yüküne, gerçekleşmiştir, cocopeat, dolarlık,
# Nearest to etkisini: uygulanan, kullanmışlardır, nedeni, ve, araştırılmıştır, sonuçlar, salisilaldehit, ordubat,
# Nearest to olur: çökük, manson, fosfin, yelpazeye, ispatı, akımdır, sebep, gaillard,
# Nearest to activities: moc, study, kromatit, biosynthesis, nötre, tangüler, cpgly, paydaşların,
# Nearest to yoğunluğu: strainlerin, soğurmanın, tarsusun, editörüarea, mıknatısın, gevrekliği, konumunda, besin,
# Nearest to sınıf: cta, yayınlarından, öğrenci, tags, i̇lköğretimde, mitteleuropa, doiklujes, dersine,
# Epoch 3/15 Iteration: 43100 Avg. Training loss: 3.6776 0.0276 sec/batch
# Epoch 3/15 Iteration: 43200 Avg. Training loss: 3.6166 0.0256 sec/batch
# Epoch 3/15 Iteration: 43300 Avg. Training loss: 3.5612 0.0254 sec/batch
# Epoch 3/15 Iteration: 43400 Avg. Training loss: 3.6129 0.0256 sec/batch
# Epoch 3/15 Iteration: 43500 Avg. Training loss: 3.6128 0.0255 sec/batch
# Epoch 3/15 Iteration: 43600 Avg. Training loss: 3.6292 0.0256 sec/batch
# Epoch 3/15 Iteration: 43700 Avg. Training loss: 3.7002 0.0257 sec/batch
# Epoch 3/15 Iteration: 43800 Avg. Training loss: 3.6597 0.0255 sec/batch
# Epoch 3/15 Iteration: 43900 Avg. Training loss: 3.6816 0.0254 sec/batch
# Epoch 3/15 Iteration: 44000 Avg. Training loss: 3.6943 0.0253 sec/batch
# Nearest to used: was, statistical, seleksiyonunda, four, tmin, folks, cmr, as,
# Nearest to and: of, the, in, by, to, for, is, on,
# Nearest to göre: ise, tablo, toplam, ve, sonuçları, elde, değerleri, edilmiştir,
# Nearest to f: r, b, if, a, e, dh, babanın, kk,
# Nearest to su: suyu, sulama, nehrinde, yönetmeliğine, dereleri, suyun, infante, artezyen,
# Nearest to as: in, have, the, and, of, with, that, different,
# Nearest to daha: olduğu, bu, ve, arasında, sahip, benzer, ile, ise,
# Nearest to on: and, of, effect, not, were, for, the, that,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, cto, sayede, asiltürk, ıslah, pikseller,
# Nearest to assessment: pestalozzae, yree, i̇mmunohistokimyasal, şefliklerinde, aliğdır, definitely, organically, prevent,
# Nearest to azalma: artışın, rolünün, ortaklıkları, küçükken, mises, cocopeat, yüküne, gerçekleşmiştir,
# Nearest to etkisini: uygulanan, kullanmışlardır, nedeni, yayınıma, ordubat, bileflenlerden, okuyan, araştırılmıştır,
# Nearest to olur: çökük, manson, ispatı, fosfin, yelpazeye, akımdır, ifadeyi, iif,
# Nearest to activities: study, moc, nötre, cpgly, tangüler, kromatit, paydaşların, valutec,
# Nearest to yoğunluğu: strainlerin, tarsusun, konumunda, editörüarea, müdürlüğünün, wesemael, dikkate, gevrekliği,
# Nearest to sınıf: öğrenci, i̇lköğretimde, dersine, olmadığı, matematik, mitteleuropa, doiklujes, yayınlarından,
# Epoch 3/15 Iteration: 44100 Avg. Training loss: 3.5823 0.0276 sec/batch
# Epoch 3/15 Iteration: 44200 Avg. Training loss: 3.6979 0.0255 sec/batch
# Epoch 3/15 Iteration: 44300 Avg. Training loss: 3.6499 0.0253 sec/batch
# Epoch 3/15 Iteration: 44400 Avg. Training loss: 3.6595 0.0256 sec/batch
# Epoch 3/15 Iteration: 44500 Avg. Training loss: 3.6479 0.0258 sec/batch
# Epoch 3/15 Iteration: 44600 Avg. Training loss: 3.5243 0.0259 sec/batch
# Epoch 3/15 Iteration: 44700 Avg. Training loss: 3.5542 0.0255 sec/batch
# Epoch 3/15 Iteration: 44800 Avg. Training loss: 3.6142 0.0254 sec/batch
# Epoch 3/15 Iteration: 44900 Avg. Training loss: 3.6144 0.0253 sec/batch
# Epoch 3/15 Iteration: 45000 Avg. Training loss: 3.6817 0.0254 sec/batch
# Nearest to used: was, statistical, seleksiyonunda, four, tmin, package, as, folks,
# Nearest to and: of, the, in, by, was, for, on, were,
# Nearest to göre: tablo, ise, değerleri, toplam, sonuçları, edilmiştir, elde, oranı,
# Nearest to f: r, b, kk, e, marthaziran, kaynaklanabilirliği, a, olarakbelirlenmiştir,
# Nearest to su: suyu, sulama, nehrinde, yönetmeliğine, dereleri, infante, artezyen, suyun,
# Nearest to as: in, have, different, and, erginleri, the, memduh, ksilen,
# Nearest to daha: olduğu, arasında, benzer, ve, yüksek, sahip, bu, düşük,
# Nearest to on: and, effect, of, journal, meram, p, vinca, elmastas,
# Nearest to görüntü: görüntünün, görüntüde, cto, kameranın, asiltürk, ıslah, pikseller, sayede,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, pestalozzae, aliğdır, organically, yree, genelmüdürlüü, definitely,
# Nearest to azalma: artışın, rolünün, kıyasla, cocopeat, yüksek, olduğu, etkisinin, pestisidlerin,
# Nearest to etkisini: uygulanan, çalışmada, araştırılmıştır, nedeni, kullanmışlardır, etkisinin, ve, tedaviye,
# Nearest to olur: çökük, manson, ispatı, fosfin, yelpazeye, akımdır, eğer, ifadeyi,
# Nearest to activities: study, moc, nötre, myrtus, methanolic, biosynthesis, kromatit, cpgly,
# Nearest to yoğunluğu: strainlerin, tarsusun, editörüarea, konumunda, gevrekliği, dikkate, caltha, mıknatısın,
# Nearest to sınıf: öğrenci, dersine, i̇lköğretimde, olmadığı, doiklujes, cta, matematik, mitteleuropa,
# Epoch 3/15 Iteration: 45100 Avg. Training loss: 3.7329 0.0275 sec/batch
# Epoch 3/15 Iteration: 45200 Avg. Training loss: 3.6896 0.0256 sec/batch
# Epoch 3/15 Iteration: 45300 Avg. Training loss: 3.6953 0.0254 sec/batch
# Epoch 3/15 Iteration: 45400 Avg. Training loss: 3.6662 0.0256 sec/batch
# Epoch 3/15 Iteration: 45500 Avg. Training loss: 3.6770 0.0252 sec/batch
# Epoch 3/15 Iteration: 45600 Avg. Training loss: 3.6219 0.0257 sec/batch
# Epoch 3/15 Iteration: 45700 Avg. Training loss: 3.5767 0.0261 sec/batch
# Epoch 3/15 Iteration: 45800 Avg. Training loss: 3.6171 0.0262 sec/batch
# Epoch 3/15 Iteration: 45900 Avg. Training loss: 3.7067 0.0265 sec/batch
# Epoch 3/15 Iteration: 46000 Avg. Training loss: 3.6644 0.0260 sec/batch
# Nearest to used: was, statistical, four, seleksiyonunda, tmin, package, as, toksikoloji,
# Nearest to and: of, the, in, by, was, for, were, with,
# Nearest to göre: tablo, ise, değerleri, toplam, sonuçları, ve, elde, edilen,
# Nearest to f: r, b, olarakbelirlenmiştir, dh, babanın, fh, kk, marthaziran,
# Nearest to su: suyu, sulama, yönetmeliğine, nehrinde, suyun, infante, artezyen, dereleri,
# Nearest to as: in, have, the, different, and, with, wereobserved, positive,
# Nearest to daha: yüksek, olduğu, düşük, benzer, ve, arasında, görülmektedir, sahip,
# Nearest to on: effect, and, of, were, görüldüğü, meram, not, was,
# Nearest to görüntü: görüntünün, görüntüde, cto, kameranın, asiltürk, ıslah, pikseller, görüntülerin,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, pestalozzae, lerner, organically, yree, nrcs, genelmüdürlüü,
# Nearest to azalma: artışın, rolünün, kıyasla, cocopeat, küçükken, gerçekleşmiştir, ortaklıkları, mises,
# Nearest to etkisini: uygulanan, kullanmışlardır, araştırılmıştır, çalışmada, nedeni, etkisinin, ve, dağilim,
# Nearest to olur: çökük, manson, fosfin, yelpazeye, ispatı, akımdır, sebep, gaillard,
# Nearest to activities: study, cpgly, moc, nötre, myrtus, methanolic, tripathi, kromatit,
# Nearest to yoğunluğu: strainlerin, tarsusun, gevrekliği, editörüarea, konumunda, dikkate, caltha, mıknatısın,
# Nearest to sınıf: öğrenci, olmadığı, dersine, i̇lköğretimde, doiklujes, cta, yayınlarından, matematik,
# Epoch 3/15 Iteration: 46100 Avg. Training loss: 3.7142 0.0276 sec/batch
# Epoch 4/15 Iteration: 46200 Avg. Training loss: 3.8257 0.0180 sec/batch
# Epoch 4/15 Iteration: 46300 Avg. Training loss: 3.8113 0.0253 sec/batch
# Epoch 4/15 Iteration: 46400 Avg. Training loss: 3.7989 0.0267 sec/batch
# Epoch 4/15 Iteration: 46500 Avg. Training loss: 3.7858 0.0268 sec/batch
# Epoch 4/15 Iteration: 46600 Avg. Training loss: 3.7362 0.0263 sec/batch
# Epoch 4/15 Iteration: 46700 Avg. Training loss: 3.6425 0.0253 sec/batch
# Epoch 4/15 Iteration: 46800 Avg. Training loss: 3.6742 0.0254 sec/batch
# Epoch 4/15 Iteration: 46900 Avg. Training loss: 3.6071 0.0253 sec/batch
# Epoch 4/15 Iteration: 47000 Avg. Training loss: 3.5500 0.0253 sec/batch
# Nearest to used: was, statistical, four, tmin, as, tests, the, are,
# Nearest to and: of, the, by, in, for, with, is, on,
# Nearest to göre: tablo, ise, değerleri, sonuçları, toplam, verilmiştir, oranı, ve,
# Nearest to f: r, çarpanlar, kaynaklanabilirliği, babanın, sağlanmamış, kk, fh, dh,
# Nearest to su: suyu, sulama, infante, yönetmeliğine, nehrinde, suyun, kirişlerden, senaryoları,
# Nearest to as: in, have, different, the, and, terms, formally, that,
# Nearest to daha: olduğu, görülmektedir, bu, değişimdir, sahip, artış, yüksek, düşük,
# Nearest to on: and, of, effect, geotextiles, for, eleco, adversarial, design,
# Nearest to görüntü: görüntünün, görüntüde, görüntülerin, kameranın, pikseller, cto, ıslah, asiltürk,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, lerner, yree, cephenin, prevent, gitmektedirler, pestalozzae,
# Nearest to azalma: artışın, mises, yüküne, küçükken, rolünün, sayılarında, ortaklıkları, kıyasla,
# Nearest to etkisini: uygulanan, kullanmışlardır, araştırılmıştır, çalışmada, nedeni, tedaviye, geobiandwi, etkisinin,
# Nearest to olur: çökük, ispatı, manson, ifadeyi, attachment, burada, akımdır, iif,
# Nearest to activities: study, cpgly, moc, nötre, kromatit, valutec, methanolic, myrtus,
# Nearest to yoğunluğu: strainlerin, konumunda, mıknatısın, editörüarea, tarsusun, gevrekliği, bağıntısında, akımı,
# Nearest to sınıf: olmadığı, dersine, i̇lköğretimde, doiklujes, öğrenci, cta, yayınlarından, mitteleuropa,
# Epoch 4/15 Iteration: 47100 Avg. Training loss: 3.5501 0.0277 sec/batch
# Epoch 4/15 Iteration: 47200 Avg. Training loss: 3.6634 0.0254 sec/batch
# Epoch 4/15 Iteration: 47300 Avg. Training loss: 3.6637 0.0255 sec/batch
# Epoch 4/15 Iteration: 47400 Avg. Training loss: 3.6469 0.0252 sec/batch
# Epoch 4/15 Iteration: 47500 Avg. Training loss: 3.6592 0.0254 sec/batch
# Epoch 4/15 Iteration: 47600 Avg. Training loss: 3.6646 0.0254 sec/batch
# Epoch 4/15 Iteration: 47700 Avg. Training loss: 3.6821 0.0253 sec/batch
# Epoch 4/15 Iteration: 47800 Avg. Training loss: 3.6966 0.0254 sec/batch
# Epoch 4/15 Iteration: 47900 Avg. Training loss: 3.6984 0.0253 sec/batch
# Epoch 4/15 Iteration: 48000 Avg. Training loss: 3.6378 0.0253 sec/batch
# Nearest to used: was, statistical, four, tmin, the, are, as, study,
# Nearest to and: of, the, by, in, for, journal, on, is,
# Nearest to göre: tablo, ise, toplam, oranı, değerleri, sonuçları, ve, verilmiştir,
# Nearest to f: r, çarpanlar, b, kaynaklanabilirliği, kk, e, if, babanın,
# Nearest to su: suyu, sulama, nehrinde, suyun, yönetmeliğine, infante, suyunun, senaryoları,
# Nearest to as: have, in, different, the, terms, formally, that, used,
# Nearest to daha: olduğu, arasında, bu, düşük, ise, artış, görülmektedir, benzer,
# Nearest to on: and, of, geotextiles, effect, for, design, eleco, wires,
# Nearest to görüntü: görüntünün, görüntüde, asiltürk, kameranın, ıslah, pikseller, cto, bilgisayarla,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, lerner, yree, cephenin, nrcs, prevent, httpsdxdoiorggmbd,
# Nearest to azalma: artışın, yüküne, mises, küçükken, sayılarında, rolünün, etkisinin, kıyasla,
# Nearest to etkisini: kullanmışlardır, çalışmada, uygulanan, araştırılmıştır, nedeni, tedaviye, bulunmuşlardır, geobiandwi,
# Nearest to olur: çökük, ispatı, manson, attachment, iif, ifadeyi, burada, eder,
# Nearest to activities: study, cpgly, moc, nötre, tangüler, kromatit, tripathi, myrtus,
# Nearest to yoğunluğu: mıknatısın, dikkate, konumunda, bağıntısında, editörüarea, şekilden, strainlerin, soğurmanın,
# Nearest to sınıf: dersine, cta, i̇lköğretimde, olmadığı, mitteleuropa, doiklujes, yayınlarından, leveraging,
# Epoch 4/15 Iteration: 48100 Avg. Training loss: 3.7213 0.0275 sec/batch
# Epoch 4/15 Iteration: 48200 Avg. Training loss: 3.6091 0.0255 sec/batch
# Epoch 4/15 Iteration: 48300 Avg. Training loss: 3.6086 0.0253 sec/batch
# Epoch 4/15 Iteration: 48400 Avg. Training loss: 3.7014 0.0253 sec/batch
# Epoch 4/15 Iteration: 48500 Avg. Training loss: 3.6028 0.0253 sec/batch
# Epoch 4/15 Iteration: 48600 Avg. Training loss: 3.6476 0.0254 sec/batch
# Epoch 4/15 Iteration: 48700 Avg. Training loss: 3.6705 0.0252 sec/batch
# Epoch 4/15 Iteration: 48800 Avg. Training loss: 3.6435 0.0254 sec/batch
# Epoch 4/15 Iteration: 48900 Avg. Training loss: 3.6343 0.0255 sec/batch
# Epoch 4/15 Iteration: 49000 Avg. Training loss: 3.6500 0.0255 sec/batch
# Nearest to used: was, four, statistical, tmin, folks, toksikoloji, are, kahveci̇,
# Nearest to and: of, the, by, in, for, journal, on, with,
# Nearest to göre: tablo, toplam, değerleri, ise, elde, oranı, edilmiştir, sonuçları,
# Nearest to f: r, çarpanlar, kaynaklanabilirliği, fh, e, a, dh, b,
# Nearest to su: suyu, sulama, nehrinde, suyun, yönetmeliğine, artezyen, suyunun, dereleri,
# Nearest to as: have, in, the, that, different, formally, with, results,
# Nearest to daha: artış, arasında, görülmektedir, yüksek, dikimlerde, düşük, bu, olduğu,
# Nearest to on: and, of, effect, were, geotextiles, for, eleco, design,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, cto, asiltürk, pikseller, ıslah, görüntülerin,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, lerner, yree, organically, nrcs, samuel, cephenin,
# Nearest to azalma: artışın, yüküne, mises, küçükken, sayılarında, rolünün, etkisinin, kıyasla,
# Nearest to etkisini: kullanmışlardır, uygulanan, çalışmada, araştırılmıştır, geobiandwi, nedeni, tedaviye, okuyan,
# Nearest to olur: çökük, manson, ispatı, iif, attachment, olasılığını, eder, ifadeyi,
# Nearest to activities: study, cpgly, moc, nötre, tripathi, paydaşların, tangüler, methanolic,
# Nearest to yoğunluğu: mıknatısın, konumunda, editörüarea, strainlerin, akçaköy, bağıntısında, tarsusun, opposite,
# Nearest to sınıf: i̇lköğretimde, dersine, cta, görmekte, mitteleuropa, doiklujes, olmadığı, leveraging,
# Epoch 4/15 Iteration: 49100 Avg. Training loss: 3.6534 0.0278 sec/batch
# Epoch 4/15 Iteration: 49200 Avg. Training loss: 3.6297 0.0257 sec/batch
# Epoch 4/15 Iteration: 49300 Avg. Training loss: 3.7127 0.0254 sec/batch
# Epoch 4/15 Iteration: 49400 Avg. Training loss: 3.6279 0.0255 sec/batch
# Epoch 4/15 Iteration: 49500 Avg. Training loss: 3.7258 0.0255 sec/batch
# Epoch 4/15 Iteration: 49600 Avg. Training loss: 3.6236 0.0254 sec/batch
# Epoch 4/15 Iteration: 49700 Avg. Training loss: 3.6887 0.0253 sec/batch
# Epoch 4/15 Iteration: 49800 Avg. Training loss: 3.6085 0.0254 sec/batch
# Epoch 4/15 Iteration: 49900 Avg. Training loss: 3.6202 0.0252 sec/batch
# Epoch 4/15 Iteration: 50000 Avg. Training loss: 3.6615 0.0253 sec/batch
# Nearest to used: was, statistical, four, toksikoloji, emm, folks, kahveci̇, basing,
# Nearest to and: of, the, in, by, for, on, journal, with,
# Nearest to göre: toplam, tablo, elde, ise, değerleri, bu, edilmiştir, ve,
# Nearest to f: r, açısındaki, kaynaklanabilirliği, çarpanlar, dh, sağlanmamış, yapacak, b,
# Nearest to su: suyu, sulama, nehrinde, suyun, dereleri, artezyen, suyunun, infante,
# Nearest to as: have, in, different, that, the, worse, with, of,
# Nearest to daha: yüksek, düşük, artış, olduğu, görülmektedir, ile, arasında, bu,
# Nearest to on: and, were, effect, of, geotextiles, dmd, eleco, for,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, cto, asiltürk, ıslah, pikseller, markov,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, yree, organically, lerner, tutulan, jjhazmat, olası,
# Nearest to azalma: artışın, mises, yüküne, kıyasla, etkisinin, rolünün, küçükken, sayılarında,
# Nearest to etkisini: çalışmada, kullanmışlardır, uygulanan, araştırılmıştır, geobiandwi, nedeni, vetoprak, etkilerini,
# Nearest to olur: çökük, manson, ispatı, attachment, yelpazeye, eder, eğer, scaling,
# Nearest to activities: study, tripathi, cpgly, nötre, moc, tangüler, methanolic, paydaşların,
# Nearest to yoğunluğu: mıknatısın, dikkate, konumunda, akçaköy, bağıntısında, akımı, strainlerin, editörüarea,
# Nearest to sınıf: i̇lköğretimde, cta, mitteleuropa, dersine, görmekte, doiklujes, yayınlarından, leveraging,
# Epoch 4/15 Iteration: 50100 Avg. Training loss: 3.6206 0.0275 sec/batch
# Epoch 4/15 Iteration: 50200 Avg. Training loss: 3.6375 0.0253 sec/batch
# Epoch 4/15 Iteration: 50300 Avg. Training loss: 3.7129 0.0253 sec/batch
# Epoch 4/15 Iteration: 50400 Avg. Training loss: 3.7746 0.0253 sec/batch
# Epoch 4/15 Iteration: 50500 Avg. Training loss: 3.7010 0.0253 sec/batch
# Epoch 4/15 Iteration: 50600 Avg. Training loss: 3.6477 0.0254 sec/batch
# Epoch 4/15 Iteration: 50700 Avg. Training loss: 3.6516 0.0254 sec/batch
# Epoch 4/15 Iteration: 50800 Avg. Training loss: 3.6302 0.0254 sec/batch
# Epoch 4/15 Iteration: 50900 Avg. Training loss: 3.7188 0.0253 sec/batch
# Epoch 4/15 Iteration: 51000 Avg. Training loss: 3.6735 0.0253 sec/batch
# Nearest to used: was, four, statistical, are, toksikoloji, kahveci̇, basing, tmin,
# Nearest to and: of, the, in, for, by, on, journal, with,
# Nearest to göre: toplam, tablo, ise, değerleri, sonuçları, edilmiştir, oranı, elde,
# Nearest to f: r, a, following, açısındaki, b, e, çarpanlar, if,
# Nearest to su: suyu, sulama, nehrinde, suyun, dereleri, infante, yönetmeliğine, artezyen,
# Nearest to as: in, have, the, of, that, different, and, worse,
# Nearest to daha: yüksek, bu, olduğu, arasında, düşük, bir, benzer, görülmektedir,
# Nearest to on: and, effect, were, of, geotextiles, wires, mm, eleco,
# Nearest to görüntü: görüntünün, görüntüde, asiltürk, kameranın, cto, pikseller, ıslah, kaldığından,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, pestalozzae, olası, yree, organically, lerner, jjhazmat,
# Nearest to azalma: artışın, yüküne, rolünün, mises, kıyasla, etkisinin, küçükken, sayılarında,
# Nearest to etkisini: çalışmada, uygulanan, kullanmışlardır, vetoprak, araştırılmıştır, geobiandwi, ve, yayınıma,
# Nearest to olur: manson, çökük, ispatı, yelpazeye, attachment, olasılığını, scaling, dolaysız,
# Nearest to activities: study, cpgly, methanolic, moc, nötre, activity, valutec, tripathi,
# Nearest to yoğunluğu: strainlerin, mıknatısın, bağıntısında, akçaköy, konumunda, dikkate, uygulamalarda, soğurmanın,
# Nearest to sınıf: dersine, mitteleuropa, cta, i̇lköğretimde, görmekte, doiklujes, yayınlarından, hendek,
# Epoch 4/15 Iteration: 51100 Avg. Training loss: 3.6799 0.0274 sec/batch
# Epoch 4/15 Iteration: 51200 Avg. Training loss: 3.7434 0.0252 sec/batch
# Epoch 4/15 Iteration: 51300 Avg. Training loss: 3.6753 0.0254 sec/batch
# Epoch 4/15 Iteration: 51400 Avg. Training loss: 3.7077 0.0253 sec/batch
# Epoch 4/15 Iteration: 51500 Avg. Training loss: 3.7132 0.0254 sec/batch
# Epoch 4/15 Iteration: 51600 Avg. Training loss: 3.7056 0.0255 sec/batch
# Epoch 4/15 Iteration: 51700 Avg. Training loss: 3.5961 0.0253 sec/batch
# Epoch 4/15 Iteration: 51800 Avg. Training loss: 3.7257 0.0255 sec/batch
# Epoch 4/15 Iteration: 51900 Avg. Training loss: 3.6700 0.0253 sec/batch
# Epoch 4/15 Iteration: 52000 Avg. Training loss: 3.6597 0.0256 sec/batch
# Nearest to used: was, four, statistical, as, toksikoloji, with, analyzed, tmin,
# Nearest to and: of, the, in, for, by, journal, on, to,
# Nearest to göre: tablo, toplam, ise, değerleri, elde, bu, sonuçları, ve,
# Nearest to f: r, b, a, e, dh, following, çarpanlar, fh,
# Nearest to su: suyu, sulama, suyun, dereleri, infante, artezyen, yönetmeliğine, nehrinde,
# Nearest to as: in, have, the, and, of, with, that, to,
# Nearest to daha: olduğu, bu, yüksek, arasında, sahip, benzer, artış, düşük,
# Nearest to on: and, effect, of, eleco, were, for, geotextiles, was,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, asiltürk, görüntülerin, cto, pikseller, ıslah,
# Nearest to assessment: i̇mmunohistokimyasal, yree, şefliklerinde, pestalozzae, olası, organically, cephenin, lerner,
# Nearest to azalma: artışın, yüküne, kıyasla, küçükken, sayılarında, mises, rolünün, etkisinin,
# Nearest to etkisini: uygulanan, kullanmışlardır, çalışmada, ve, vetoprak, geobiandwi, etkilerini, araştırılmıştır,
# Nearest to olur: manson, çökük, attachment, dolaysız, olasılığını, ispatı, iif, eğer,
# Nearest to activities: study, methanolic, activity, tripathi, cpgly, moc, nötre, myrtus,
# Nearest to yoğunluğu: strainlerin, bağıntısında, mıknatısın, dikkate, akçaköy, şekilden, konumunda, denklemi,
# Nearest to sınıf: cta, mitteleuropa, dersine, i̇lköğretimde, yayınlarından, görmekte, doiklujes, hendek,
# Epoch 4/15 Iteration: 52100 Avg. Training loss: 3.5984 0.0276 sec/batch
# Epoch 4/15 Iteration: 52200 Avg. Training loss: 3.5763 0.0255 sec/batch
# Epoch 4/15 Iteration: 52300 Avg. Training loss: 3.6940 0.0254 sec/batch
# Epoch 4/15 Iteration: 52400 Avg. Training loss: 3.6363 0.0253 sec/batch
# Epoch 4/15 Iteration: 52500 Avg. Training loss: 3.6107 0.0252 sec/batch
# Epoch 4/15 Iteration: 52600 Avg. Training loss: 3.7200 0.0253 sec/batch
# Epoch 4/15 Iteration: 52700 Avg. Training loss: 3.6200 0.0253 sec/batch
# Epoch 4/15 Iteration: 52800 Avg. Training loss: 3.6280 0.0254 sec/batch
# Epoch 4/15 Iteration: 52900 Avg. Training loss: 3.7496 0.0252 sec/batch
# Epoch 4/15 Iteration: 53000 Avg. Training loss: 3.6230 0.0254 sec/batch
# Nearest to used: was, four, analyzed, toksikoloji, with, statistical, study, tmin,
# Nearest to and: of, the, in, for, by, on, journal, was,
# Nearest to göre: tablo, değerleri, toplam, ise, sonuçları, elde, edilmiştir, edilen,
# Nearest to f: r, b, a, fh, sağlanmamış, e, olarakbelirlenmiştir, dh,
# Nearest to su: sulama, suyu, suyun, dereleri, infante, artezyen, suyunun, yönetmeliğine,
# Nearest to as: in, have, the, that, and, with, results, other,
# Nearest to daha: yüksek, arasında, olduğu, artış, bu, benzer, farklı, sahip,
# Nearest to on: and, effect, were, of, was, geotextiles, for, the,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, asiltürk, cto, görüntülerin, ıslah, pikseller,
# Nearest to assessment: i̇mmunohistokimyasal, pestalozzae, yree, şefliklerinde, lerner, mandibulası, genelmüdürlüü, organically,
# Nearest to azalma: artışın, kıyasla, yüküne, rolünün, etkisinin, dolarlık, mises, gerçekleşmiştir,
# Nearest to etkisini: kullanmışlardır, uygulanan, ve, çalışmada, etkilerini, nedeni, vetoprak, yayınıma,
# Nearest to olur: manson, çökük, attachment, ispatı, olasılığını, fosfin, dolaysız, yelpazeye,
# Nearest to activities: study, activity, methanolic, nötre, moc, cpgly, myrtus, tripathi,
# Nearest to yoğunluğu: strainlerin, akçaköy, bağıntısında, wesemael, mıknatısın, dikkate, konumunda, ölçülen,
# Nearest to sınıf: mitteleuropa, dersine, cta, görmekte, i̇lköğretimde, yayınlarından, hendek, absorpsiyonu,
# Epoch 4/15 Iteration: 53100 Avg. Training loss: 3.6404 0.0277 sec/batch
# Epoch 4/15 Iteration: 53200 Avg. Training loss: 3.5356 0.0253 sec/batch
# Epoch 4/15 Iteration: 53300 Avg. Training loss: 3.6189 0.0254 sec/batch
# Epoch 4/15 Iteration: 53400 Avg. Training loss: 3.5873 0.0253 sec/batch
# Epoch 4/15 Iteration: 53500 Avg. Training loss: 3.5682 0.0252 sec/batch
# Epoch 4/15 Iteration: 53600 Avg. Training loss: 3.6763 0.0253 sec/batch
# Epoch 4/15 Iteration: 53700 Avg. Training loss: 3.1774 0.0253 sec/batch
# Epoch 4/15 Iteration: 53800 Avg. Training loss: 3.0615 0.0253 sec/batch
# Epoch 4/15 Iteration: 53900 Avg. Training loss: 3.2235 0.0253 sec/batch
# Epoch 4/15 Iteration: 54000 Avg. Training loss: 3.3083 0.0254 sec/batch
# Nearest to used: was, toksikoloji, statistical, four, analyzed, emm, uygunsuzluk, europan,
# Nearest to and: of, the, in, for, by, on, from, that,
# Nearest to göre: ise, toplam, tablo, elde, bu, değerleri, ve, edilen,
# Nearest to f: r, b, a, e, k, m, jt, d,
# Nearest to su: suyu, sulama, suyun, suyunun, alnmfltr, ürünleri, nehrinde, profillerini,
# Nearest to as: in, have, the, and, of, that, different, other,
# Nearest to daha: bu, ve, ile, yüksek, olarak, sahip, bir, ise,
# Nearest to on: and, of, effect, were, geotextiles, p, for, the,
# Nearest to görüntü: görüntünün, görüntüde, kameranın, asiltürk, görüntülerin, cto, ıslah, markov,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, yree, pestalozzae, mandibulası, lerner, değerlendirmelerle, aliğdır,
# Nearest to azalma: artışın, kifli, yüküne, etkisinin, kıyasla, yüksek, rolünün, maxent,
# Nearest to etkisini: ve, uygulanan, sonuçlar, etkilerini, etkisi, nedeni, belirlenmifl, kullanmışlardır,
# Nearest to olur: çökük, manson, ispatı, fosfin, attachment, olasılığını, kirpi, eder,
# Nearest to activities: study, activity, cpgly, methanolic, tangüler, nötre, moc, valutec,
# Nearest to yoğunluğu: strainlerin, akçaköy, bağıntısında, wesemael, mıknatısın, eşitliğinde, caltha, ölçülen,
# Nearest to sınıf: mitteleuropa, dersine, cta, görmekte, i̇lköğretimde, yayınlarından, ilginçlik, hendek,
# Epoch 4/15 Iteration: 54100 Avg. Training loss: 3.5428 0.0275 sec/batch
# Epoch 4/15 Iteration: 54200 Avg. Training loss: 3.5642 0.0252 sec/batch
# Epoch 4/15 Iteration: 54300 Avg. Training loss: 3.4922 0.0256 sec/batch
# Epoch 4/15 Iteration: 54400 Avg. Training loss: 3.5107 0.0255 sec/batch
# Epoch 4/15 Iteration: 54500 Avg. Training loss: 3.3993 0.0253 sec/batch
# Epoch 4/15 Iteration: 54600 Avg. Training loss: 3.4685 0.0252 sec/batch
# Epoch 4/15 Iteration: 54700 Avg. Training loss: 3.4448 0.0253 sec/batch
# Epoch 4/15 Iteration: 54800 Avg. Training loss: 3.7034 0.0253 sec/batch
# Epoch 4/15 Iteration: 54900 Avg. Training loss: 3.6445 0.0254 sec/batch
# Epoch 4/15 Iteration: 55000 Avg. Training loss: 3.6687 0.0253 sec/batch
# Nearest to used: was, statistical, four, toksikoloji, folks, europan, resins, tests,
# Nearest to and: of, the, in, for, by, on, to, with,
# Nearest to göre: ise, toplam, tablo, ile, değerleri, bu, ve, oranı,
# Nearest to f: r, b, a, e, sağlanmamış, çarpanlar, marthaziran, açısındaki,
# Nearest to su: sulama, suyu, suyun, dereleri, nehrinde, suyunun, artezyen, alnmfltr,
# Nearest to as: have, in, and, the, that, etkime, investigated, to,
# Nearest to daha: yüksek, bu, ile, sahip, iyi, ve, benzer, arasında,
# Nearest to on: and, effect, of, geotextiles, were, for, to, callister,
# Nearest to görüntü: görüntünün, kameranın, görüntüde, görüntülerin, asiltürk, görüntüleri, cto, pikseller,
# Nearest to assessment: i̇mmunohistokimyasal, şefliklerinde, yree, lerner, cephenin, mandibulası, kaynağinda, pestalozzae,
# Nearest to azalma: artışın, kıyasla, yüküne, kifli, rolünün, etkisinin, maxent, ambigua,
# Nearest to etkisini: ve, uygulanan, kullanmışlardır, çalışmada, belirlenmifl, sonuçlar, etkilerini, etkisinin,
# Nearest to olur: manson, çökük, ispatı, fosfin, eğer, kirpi, olasılığını, akımdır,
# Nearest to activities: activity, cpgly, study, valutec, moc, tangüler, methanolic, nötre,
# Nearest to yoğunluğu: strainlerin, bağıntısında, mıknatısın, akçaköy, wesemael, photoelectric, şekilden, eşitliğinde,
# Nearest to sınıf: dersine, mitteleuropa, cta, i̇lköğretimde, görmekte, yayınlarından, ilginçlik, hendek,
# Epoch 4/15 Iteration: 55100 Avg. Training loss: 3.7600 0.0275 sec/batch
# Epoch 4/15 Iteration: 55200 Avg. Training loss: 3.7250 0.0256 sec/batch
# Epoch 4/15 Iteration: 55300 Avg. Training loss: 3.7816 0.0256 sec/batch
# Epoch 4/15 Iteration: 55400 Avg. Training loss: 3.6586 0.0256 sec/batch
# Epoch 4/15 Iteration: 55500 Avg. Training loss: 3.6716 0.0255 sec/batch
# Epoch 4/15 Iteration: 55600 Avg. Training loss: 3.6485 0.0257 sec/batch
# Epoch 4/15 Iteration: 55700 Avg. Training loss: 3.6995 0.0258 sec/batch
# Epoch 4/15 Iteration: 55800 Avg. Training loss: 3.6769 0.0256 sec/batch
# Epoch 4/15 Iteration: 55900 Avg. Training loss: 3.6561 0.0253 sec/batch
# Epoch 4/15 Iteration: 56000 Avg. Training loss: 3.6454 0.0252 sec/batch
# Nearest to used: was, statistical, four, the, toksikoloji, folks, as, study,
# Nearest to and: of, the, in, for, on, by, with, to,
# Nearest to göre: ise, değerleri, toplam, tablo, ile, ve, oranı, arasında,
# Nearest to f: r, b, a, e, fh, sağlanmamış, olarakbelirlenmiştir, açısındaki,
# Nearest to su: sulama, suyu, suyun, suyunun, dereleri, artezyen, infante, nehrinde,
# Nearest to as: in, and, have, the, that, different, investigated, of,
# Nearest to daha: yüksek, bu, arasında, ile, ve, benzer, olduğu, sahip,
# Nearest to on: and, effect, of, were, for, geotextiles, the, was,
# Nearest to görüntü: görüntünün, kameranın, görüntülerin, görüntüde, asiltürk, kaldığından, markov, sayede,
# Nearest to assessment: i̇mmunohistokimyasal, yree, şefliklerinde, kaynağinda, polinomlarla, httpsdxdoiorggmbd, pestalozzae, lerner,
# Nearest to azalma: artışın, kıyasla, yüküne, etkisinin, kifli, maxent, değerlerinde, mises,
# Nearest to etkisini: ve, çalışmada, uygulanan, etkilerini, kullanmışlardır, sonuçlar, araştırılmıştır, etkisinin,
# Nearest to olur: manson, ispatı, çökük, fosfin, eğer, gaillard, attachment, kirpi,
# Nearest to activities: activity, study, cpgly, methanolic, moc, tangüler, modellenmiştir, lupinus,
# Nearest to yoğunluğu: strainlerin, bağıntısında, photoelectric, wesemael, şekilden, mıknatısın, tarsusun, akçaköy,
# Nearest to sınıf: mitteleuropa, dersine, cta, i̇lköğretimde, görmekte, engellemiştir, verilmiştir, stillerine,
# Epoch 4/15 Iteration: 56100 Avg. Training loss: 3.7154 0.0276 sec/batch
# Epoch 4/15 Iteration: 56200 Avg. Training loss: 3.5276 0.0253 sec/batch
# Epoch 4/15 Iteration: 56300 Avg. Training loss: 3.5827 0.0252 sec/batch
# Epoch 4/15 Iteration: 56400 Avg. Training loss: 3.5892 0.0256 sec/batch
# Epoch 4/15 Iteration: 56500 Avg. Training loss: 3.6424 0.0254 sec/batch
# Epoch 4/15 Iteration: 56600 Avg. Training loss: 3.6306 0.0255 sec/batch
# Epoch 4/15 Iteration: 56700 Avg. Training loss: 3.6135 0.0254 sec/batch
# Epoch 4/15 Iteration: 56800 Avg. Training loss: 3.6370 0.0255 sec/batch
# Epoch 4/15 Iteration: 56900 Avg. Training loss: 3.6568 0.0254 sec/batch
# Epoch 4/15 Iteration: 57000 Avg. Training loss: 3.5727 0.0261 sec/batch
# Nearest to used: was, four, statistical, toksikoloji, seleksiyonunda, carried, been, europan,
# Nearest to and: of, the, in, for, by, on, with, a,
# Nearest to göre: ise, tablo, toplam, değerleri, ile, çalışmada, ve, sonuçları,
# Nearest to f: r, a, b, fh, e, following, olarakbelirlenmiştir, kaynaklanabilirliği,
# Nearest to su: sulama, suyu, suyun, suyunun, artezyen, dereleri, bektaş, nehrinde,
# Nearest to as: in, and, have, the, that, of, to, investigated,
# Nearest to daha: yüksek, ile, ve, arasında, düşük, bu, olduğu, farklı,
# Nearest to on: and, effect, of, were, for, was, geotextiles, the,
# Nearest to görüntü: görüntünün, kameranın, görüntülerin, görüntüde, asiltürk, multispektral, markov, kaldığından,
# Nearest to assessment: i̇mmunohistokimyasal, kaynağinda, yree, pestalozzae, httpsdxdoiorggmbd, şefliklerinde, mandibulası, nrcs,
# Nearest to azalma: artışın, kıyasla, yüküne, etkisinin, artış, olduğu, rolünün, paralellik,
# Nearest to etkisini: çalışmada, uygulanan, ve, etkilerini, kullanmışlardır, sonuçlar, etkisinin, araştırılmıştır,
# Nearest to olur: manson, çökük, ispatı, fosfin, gaillard, akımdır, attachment, kirpi,
# Nearest to activities: study, activity, moc, cpgly, methanolic, tangüler, radicalscavenging, lupinus,
# Nearest to yoğunluğu: strainlerin, tarsusun, wesemael, photoelectric, dikkate, editörüarea, bağıntısında, şekilden,
# Nearest to sınıf: mitteleuropa, dersine, i̇lköğretimde, görmekte, cta, transcriptomics, engellemiştir, verilmiştir,
# Epoch 4/15 Iteration: 57100 Avg. Training loss: 3.5828 0.0283 sec/batch
# Epoch 4/15 Iteration: 57200 Avg. Training loss: 3.5482 0.0260 sec/batch
# Epoch 4/15 Iteration: 57300 Avg. Training loss: 3.7203 0.0260 sec/batch
# Epoch 4/15 Iteration: 57400 Avg. Training loss: 3.8251 0.0255 sec/batch
# Epoch 4/15 Iteration: 57500 Avg. Training loss: 3.7370 0.0254 sec/batch
# Epoch 4/15 Iteration: 57600 Avg. Training loss: 3.7368 0.0252 sec/batch
# Epoch 4/15 Iteration: 57700 Avg. Training loss: 3.7071 0.0255 sec/batch
# Epoch 4/15 Iteration: 57800 Avg. Training loss: 3.6957 0.0254 sec/batch
# Epoch 4/15 Iteration: 57900 Avg. Training loss: 3.6604 0.0253 sec/batch
# Epoch 4/15 Iteration: 58000 Avg. Training loss: 3.5834 0.0254 sec/batch
# Nearest to used: was, four, been, statistical, carried, are, study, as,
# Nearest to and: of, in, the, for, by, on, with, that,
# Nearest to göre: tablo, toplam, değerleri, verilmiştir, çalışmada, sonuçları, ise, ile,
# Nearest to f: r, a, b, e, kaynaklanabilirliği, fh, k, olarakbelirlenmiştir,
# Nearest to su: sulama, suyu, suyun, dereleri, nehrinde, suyunun, buharlaşma, sulamada,
# Nearest to as: in, the, and, have, that, to, of, are,
# Nearest to daha: yüksek, arasında, artış, iyi, benzer, olduğu, farklı, düşük,
# Nearest to on: and, effect, of, for, to, the, were, with,
# Nearest to görüntü: görüntünün, görüntüde, görüntülerin, markov, asiltürk, kameranın, multispektral, görüntülerinin,
# Nearest to assessment: i̇mmunohistokimyasal, yree, httpsdxdoiorggmbd, kaynağinda, şefliklerinde, değerlendirmelerle, mgkga, bulunmamaktadır,
# Nearest to azalma: artışın, kıyasla, yüküne, etkisinin, rolünün, paralellik, maxent, sayılarında,
# Nearest to etkisini: çalışmada, kullanmışlardır, etkilerini, ve, uygulanan, araştırılmıştır, sonuçlar, belirlenmifl,
# Nearest to olur: manson, çökük, gaillard, fosfin, ispatı, kirpi, akımdır, olasılığını,
# Nearest to activities: study, activity, moc, paydaşların, cpgly, nötre, tangüler, methanolic,
# Nearest to yoğunluğu: strainlerin, dikkate, bağıntısında, tarsusun, wesemael, rotora, editörüarea, photoelectric,
# Nearest to sınıf: mitteleuropa, dersine, i̇lköğretimde, cta, görmekte, transcriptomics, engellemiştir, verilmiştir,
# Epoch 4/15 Iteration: 58100 Avg. Training loss: 3.5332 0.0276 sec/batch
# Epoch 4/15 Iteration: 58200 Avg. Training loss: 3.5787 0.0253 sec/batch
# Epoch 4/15 Iteration: 58300 Avg. Training loss: 3.5144 0.0254 sec/batch
# Epoch 4/15 Iteration: 58400 Avg. Training loss: 3.5888 0.0256 sec/batch
# Epoch 4/15 Iteration: 58500 Avg. Training loss: 3.5510 0.0256 sec/batch
# Epoch 4/15 Iteration: 58600 Avg. Training loss: 3.5784 0.0255 sec/batch
# Epoch 4/15 Iteration: 58700 Avg. Training loss: 3.5159 0.0254 sec/batch
# Epoch 4/15 Iteration: 58800 Avg. Training loss: 3.5693 0.0254 sec/batch
# Epoch 4/15 Iteration: 58900 Avg. Training loss: 3.5014 0.0254 sec/batch
# Epoch 4/15 Iteration: 59000 Avg. Training loss: 3.5715 0.0255 sec/batch
# Nearest to used: was, four, carried, seleksiyonunda, statistical, study, toksikoloji, basing,
# Nearest to and: of, the, in, for, with, by, on, to,
# Nearest to göre: ise, verilmiştir, değerleri, ve, ile, çalışmada, toplam, edilen,
# Nearest to f: r, b, a, e, k, c, if, m,
# Nearest to su: sulama, suyu, suyun, dereleri, suyunun, nehrinde, artezyen, infante,
# Nearest to as: in, and, the, of, to, have, that, for,
# Nearest to daha: yüksek, olduğu, arasında, ve, ile, çalışmada, düşük, sonuç,
# Nearest to on: and, effect, of, were, the, for, to, in,
# Nearest to görüntü: görüntünün, görüntülerin, görüntüde, asiltürk, kameranın, multispektral, markov, görüntülerinin,
# Nearest to assessment: i̇mmunohistokimyasal, yree, kaynağinda, african, şefliklerinde, httpsdxdoiorggmbd, pestalozzae, strategies,
# Nearest to azalma: artışın, kıyasla, etkisinin, yüküne, paralellik, sayılarında, rolünün, artmış,
# Nearest to etkisini: çalışmada, uygulanan, etkilerini, ve, kullanmışlardır, etkisi, araştırılmıştır, sonuçlar,
# Nearest to olur: çökük, manson, fosfin, ispatı, gaillard, kirpi, olasılığını, inaktif,
# Nearest to activities: study, activity, nötre, moc, tripathi, tangüler, lupinus, myrtus,
# Nearest to yoğunluğu: strainlerin, tarsusun, uyararak, bağıntısında, wesemael, photoelectric, editörüarea, dikkate,
# Nearest to sınıf: mitteleuropa, görmekte, dersine, öğrenci, i̇lköğretimde, cta, engellemiştir, transcriptomics,
# Epoch 4/15 Iteration: 59100 Avg. Training loss: 3.6989 0.0277 sec/batch
# Epoch 4/15 Iteration: 59200 Avg. Training loss: 3.5924 0.0254 sec/batch
# Epoch 4/15 Iteration: 59300 Avg. Training loss: 3.6756 0.0254 sec/batch
# Epoch 4/15 Iteration: 59400 Avg. Training loss: 3.5968 0.0254 sec/batch
# Epoch 4/15 Iteration: 59500 Avg. Training loss: 3.5985 0.0254 sec/batch
# Epoch 4/15 Iteration: 59600 Avg. Training loss: 3.6320 0.0253 sec/batch
# Epoch 4/15 Iteration: 59700 Avg. Training loss: 3.6224 0.0253 sec/batch
# Epoch 4/15 Iteration: 59800 Avg. Training loss: 3.6214 0.0253 sec/batch
# Epoch 4/15 Iteration: 59900 Avg. Training loss: 3.6208 0.0253 sec/batch
# Epoch 4/15 Iteration: 60000 Avg. Training loss: 3.5285 0.0254 sec/batch
# Nearest to used: was, are, statistical, study, four, carried, as, seleksiyonunda,
# Nearest to and: of, the, in, by, for, with, was, as,
# Nearest to göre: tablo, ise, toplam, değerleri, sonuçları, ve, verilmiştir, çalışmada,
# Nearest to f: r, a, b, e, k, fh, m, d,
# Nearest to su: sulama, suyu, suyun, dereleri, nehrinde, suyunun, yönetmeliğine, artezyen,
# Nearest to as: in, and, the, of, to, have, that, for,
# Nearest to daha: olduğu, arasında, görülmektedir, yüksek, ile, düşük, benzer, artış,
# Nearest to on: and, of, the, were, effect, for, was, with,
# Nearest to görüntü: görüntünün, görüntülerin, görüntüde, multispektral, asiltürk, görüntülerinin, kameranın, görüntüleri,
# Nearest to assessment: i̇mmunohistokimyasal, yree, kaynağinda, african, şefliklerinde, nrcs, pestalozzae, httpsdxdoiorggmbd,
# Nearest to azalma: artışın, kıyasla, yüküne, maxent, rolünün, sayılarında, ortaklıkları, paralellik,
# Nearest to etkisini: çalışmada, kullanmışlardır, uygulanan, etkilerini, araştırılmıştır, bulunmuşlardır, tetikleyicisi, etkisinin,
# Nearest to olur: manson, çökük, kirpi, gaillard, fosfin, ispatı, olasılığını, attachment,
# Nearest to activities: study, activity, nötre, cpgly, moc, saatlere, myrtus, tripathi,
# Nearest to yoğunluğu: strainlerin, tarsusun, editörüarea, uyararak, photoelectric, dikkate, bağıntısında, konumunda,
# Nearest to sınıf: dersine, mitteleuropa, görmekte, öğrenci, i̇lköğretimde, cta, engellemiştir, başarılarına,
# Epoch 4/15 Iteration: 60100 Avg. Training loss: 3.4762 0.0277 sec/batch
# Epoch 4/15 Iteration: 60200 Avg. Training loss: 3.5715 0.0253 sec/batch
# Epoch 4/15 Iteration: 60300 Avg. Training loss: 3.6435 0.0254 sec/batch
# Epoch 4/15 Iteration: 60400 Avg. Training loss: 3.6174 0.0255 sec/batch
# Epoch 4/15 Iteration: 60500 Avg. Training loss: 3.6624 0.0254 sec/batch
# Epoch 4/15 Iteration: 60600 Avg. Training loss: 3.6225 0.0253 sec/batch
# Epoch 4/15 Iteration: 60700 Avg. Training loss: 3.6430 0.0253 sec/batch
# Epoch 4/15 Iteration: 60800 Avg. Training loss: 3.6670 0.0254 sec/batch
# Epoch 4/15 Iteration: 60900 Avg. Training loss: 3.6075 0.0255 sec/batch
# Epoch 4/15 Iteration: 61000 Avg. Training loss: 3.5303 0.0253 sec/batch
# Nearest to used: was, are, carried, statistical, as, the, four, using,
# ...
# Nearest to f: a, m, b, s, e, t, p, d,
# Nearest to su: suyun, suya, suyu, water, sulama, tüketimi, suyunun, için,
# Nearest to as: the, in, and, of, to, for, that, this,
# Nearest to daha: ve, ile, olarak, sahip, bu, elde, en, de,
# Nearest to on: and, in, of, the, different, with, by, to,
# Nearest to görüntü: görüntüler, görüntünün, görüntülerin, görüntülerinin, piksel, görüntülerde, image, görüntüde,
# Nearest to assessment: environmental, assessing, journal, using, bulletin, exposed, these, evaluation,
# Nearest to azalma: artış, artan, oranda, buna, önemli, daha, sonunda, ise,
# Nearest to etkisini: etkisi, etkisinin, etki, için, ve, ile, incelemek, benzer,
# Nearest to olur: eder, burada, yani, böylece, edilir, neden, verir, veya,
# Nearest to activities: activity, enzyme, as, they, against, both, by, inhibition,
# Nearest to yoğunluğu: yoğunluğunun, düşen, yoğunlukları, yoğunluğunu, sayısı, parametrelerden, olduğu, hesaplanmıştır,
# Nearest to sınıf: sınıfları, sınıflarına, öğrencilerin, sınıflandırma, öğrenci, sınıfına, eğitim, sınıflar,
# Epoch 15/15 Iteration: 223100 Avg. Training loss: 3.1895 0.0279 sec/batch
# Epoch 15/15 Iteration: 223200 Avg. Training loss: 3.5442 0.0259 sec/batch
# Epoch 15/15 Iteration: 223300 Avg. Training loss: 3.5975 0.0259 sec/batch
# Epoch 15/15 Iteration: 223400 Avg. Training loss: 3.5896 0.0256 sec/batch
# Epoch 15/15 Iteration: 223500 Avg. Training loss: 3.6028 0.0256 sec/batch
# Epoch 15/15 Iteration: 223600 Avg. Training loss: 3.5595 0.0255 sec/batch
# Epoch 15/15 Iteration: 223700 Avg. Training loss: 3.4916 0.0255 sec/batch
# Epoch 15/15 Iteration: 223800 Avg. Training loss: 3.5587 0.0255 sec/batch
# Epoch 15/15 Iteration: 223900 Avg. Training loss: 3.6252 0.0257 sec/batch
# Epoch 15/15 Iteration: 224000 Avg. Training loss: 3.7394 0.0256 sec/batch
# Nearest to used: are, been, carried, method, investigated, performed, based, using,
# Nearest to and: of, the, in, by, for, to, is, study,
# Nearest to göre: en, değerleri, ile, olarak, ise, edilmiştir, toplam, tablo,
# Nearest to f: a, b, e, t, s, m, x, g,
# Nearest to su: suyun, suya, sulama, water, suyu, tüketimi, içme, buharlaşma,
# Nearest to as: the, and, in, to, it, are, of, while,
# Nearest to daha: yüksek, elde, en, sahip, ve, ile, olarak, edilen,
# Nearest to on: of, the, and, in, to, different, that, effect,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerinin, piksel, görüntülerde, görüntüden, görüntüde,
# Nearest to assessment: environmental, assessing, developed, belirlenmesi, evaluation, methodologies, edilmesinin, regression,
# Nearest to azalma: artış, değişimi, artan, artışın, artmış, birlikte, buna, azalmıştır,
# Nearest to etkisini: kullanarak, etkisi, incelemek, etkisinin, benzer, incelemişlerdir, farklı, ile,
# Nearest to olur: neden, eder, veya, gt, gerçekleşmektedir, edilir, sebep, da,
# Nearest to activities: activity, enzyme, against, important, they, aktivitelerinin, especially, güçlendirerek,
# Nearest to yoğunluğu: yoğunluğunun, düşen, parametrelerden, yoğunlukları, yoğunluğunu, yoğunluk, yoğunluğuna, yoğun,
# Nearest to sınıf: sınıfları, sınıflarına, öğrencilerin, sınıflandırma, sınıfına, öğrenci, sınıfa, sınıflar,
# Epoch 15/15 Iteration: 224100 Avg. Training loss: 3.7143 0.0279 sec/batch
# Epoch 15/15 Iteration: 224200 Avg. Training loss: 3.7605 0.0256 sec/batch
# Epoch 15/15 Iteration: 224300 Avg. Training loss: 3.7779 0.0257 sec/batch
# Epoch 15/15 Iteration: 224400 Avg. Training loss: 3.8071 0.0256 sec/batch
# Epoch 15/15 Iteration: 224500 Avg. Training loss: 3.6899 0.0256 sec/batch
# Epoch 15/15 Iteration: 224600 Avg. Training loss: 3.7090 0.0255 sec/batch
# Epoch 15/15 Iteration: 224700 Avg. Training loss: 3.7615 0.0256 sec/batch
# Epoch 15/15 Iteration: 224800 Avg. Training loss: 3.7251 0.0257 sec/batch
# Epoch 15/15 Iteration: 224900 Avg. Training loss: 3.6805 0.0261 sec/batch
# Epoch 15/15 Iteration: 225000 Avg. Training loss: 3.7884 0.0263 sec/batch
# Nearest to used: method, determine, carried, are, been, study, the, evaluated,
# Nearest to and: of, the, in, to, on, for, by, with,
# Nearest to göre: değerleri, ile, verilmiştir, en, çizelge, tablo, ve, elde,
# Nearest to f: a, b, m, h, e, g, k, x,
# Nearest to su: suyun, sulama, suyu, water, suya, ile, miktarının, tüketimi,
# Nearest to as: the, to, and, are, of, was, for, were,
# Nearest to daha: ve, ile, olarak, yüksek, en, bu, elde, sahip,
# Nearest to on: and, of, the, in, to, effect, a, different,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerde, görüntülerinin, piksel, kamera, görüntüden,
# Nearest to assessment: environmental, assessing, belirlenmesi, evaluation, regression, evaluate, developed, modelling,
# Nearest to azalma: artış, oranında, artan, incelendiğinde, değişimi, artışın, azalmıştır, görülürken,
# Nearest to etkisini: etkisi, etkisinin, yaptıkları, farklı, incelemek, araştırılmıştır, etkilediğini, belirlemişlerdir,
# Nearest to olur: edilir, eğer, eder, olmaktadır, şeklinde, gt, olursa, neden,
# Nearest to activities: activity, enzyme, against, some, their, different, of, expressed,
# Nearest to yoğunluğu: yoğunluğunun, düşen, yoğunlukları, yoğunluğunu, yoğunluk, yoğunluğundan, çalışma, hesaplanmıştır,
# Nearest to sınıf: öğrencilerin, sınıflar, öğrenci, sınıfları, sınıfta, sınıflarına, sınıfa, eğitim,
# Epoch 15/15 Iteration: 225100 Avg. Training loss: 3.6895 0.0282 sec/batch
# Epoch 15/15 Iteration: 225200 Avg. Training loss: 3.7093 0.0259 sec/batch
# Epoch 15/15 Iteration: 225300 Avg. Training loss: 3.6184 0.0253 sec/batch
# Epoch 15/15 Iteration: 225400 Avg. Training loss: 3.6124 0.0254 sec/batch
# Epoch 15/15 Iteration: 225500 Avg. Training loss: 3.6252 0.0251 sec/batch
# Epoch 15/15 Iteration: 225600 Avg. Training loss: 3.6912 0.0255 sec/batch
# Epoch 15/15 Iteration: 225700 Avg. Training loss: 3.6776 0.0251 sec/batch
# Epoch 15/15 Iteration: 225800 Avg. Training loss: 3.6853 0.0252 sec/batch
# Epoch 15/15 Iteration: 225900 Avg. Training loss: 3.6925 0.0253 sec/batch
# Epoch 15/15 Iteration: 226000 Avg. Training loss: 3.7758 0.0252 sec/batch
# Nearest to used: determine, been, method, investigated, carried, in, this, are,
# Nearest to and: of, the, in, for, study, to, with, by,
# Nearest to göre: olarak, tablo, değerleri, edilmiştir, en, ise, ile, ve,
# Nearest to f: a, m, b, s, e, x, k, h,
# Nearest to su: suyun, suyu, water, suya, sulama, tüketimi, miktarının, yardımıyla,
# Nearest to as: to, the, it, in, this, that, are, while,
# Nearest to daha: ile, ve, yüksek, en, olarak, görülmektedir, elde, ise,
# Nearest to on: and, the, of, in, a, this, different, for,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerinin, görüntülerde, piksel, görüntüde, görüntüye,
# Nearest to assessment: environmental, assessing, modelling, assess, evaluation, developed, evaluate, methodologies,
# Nearest to azalma: artış, oranında, artmış, azalmıştır, ise, olduğu, artışa, değerlerinde,
# Nearest to etkisini: etkisi, yaptıkları, kullanarak, etkisinin, incelemek, incelemişlerdir, incelemiştir, arkadaşları,
# Nearest to olur: eder, meydana, neden, sw, oluşur, edilir, şeklinde, gelerek,
# Nearest to activities: activity, against, study, enzyme, in, expressed, of, was,
# Nearest to yoğunluğu: yoğunluğunun, düşen, yoğunlukları, yoğunluğunu, yoğunluk, yoğunluğuna, yoğunluklarının, kaydedilmiştir,
# Nearest to sınıf: sınıflar, sınıfları, öğrencilerin, sınıfta, öğrenci, sınıflarına, eğitim, sınıfına,
# Epoch 15/15 Iteration: 226100 Avg. Training loss: 3.5874 0.0273 sec/batch
# Epoch 15/15 Iteration: 226200 Avg. Training loss: 3.6897 0.0252 sec/batch
# Epoch 15/15 Iteration: 226300 Avg. Training loss: 3.6319 0.0252 sec/batch
# Epoch 15/15 Iteration: 226400 Avg. Training loss: 3.7254 0.0253 sec/batch
# Epoch 15/15 Iteration: 226500 Avg. Training loss: 3.8893 0.0253 sec/batch
# Epoch 15/15 Iteration: 226600 Avg. Training loss: 3.8686 0.0253 sec/batch
# Epoch 15/15 Iteration: 226700 Avg. Training loss: 3.8408 0.0252 sec/batch
# Epoch 15/15 Iteration: 226800 Avg. Training loss: 3.7986 0.0252 sec/batch
# Epoch 15/15 Iteration: 226900 Avg. Training loss: 3.7201 0.0253 sec/batch
# Epoch 15/15 Iteration: 227000 Avg. Training loss: 3.7876 0.0252 sec/batch
# Nearest to used: been, are, method, by, according, performed, determine, the,
# Nearest to and: of, in, the, to, by, is, for, are,
# Nearest to göre: olarak, ile, ve, edilmiştir, değerleri, tablo, edilen, çalışmada,
# Nearest to f: a, x, b, m, d, h, z, k,
# Nearest to su: suyun, suyu, suya, water, sulama, tüketimine, miktarının, buharlaşma,
# Nearest to as: the, to, it, are, this, is, and, be,
# Nearest to daha: yüksek, ile, iyi, olduğu, olarak, ve, da, görülmektedir,
# Nearest to on: the, and, with, of, for, this, in, a,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerinin, görüntülerde, piksel, görüntüde, görüntüsü,
# Nearest to assessment: environmental, assessing, evaluation, modelling, assess, using, calculating, bodies,
# Nearest to azalma: artış, artışın, artışa, artmış, azalmıştır, olduğu, incelendiğinde, artışına,
# Nearest to etkisini: etkisi, yaptıkları, incelemişlerdir, etkisinin, incelemiştir, incelemek, kullanarak, etmişlerdir,
# Nearest to olur: olurlar, meydana, eder, gerçekleşir, gelerek, neden, edilir, çünkü,
# Nearest to activities: activity, enzyme, aktiviteleri, against, studies, of, aktivitelerinin, aktivitesi,
# Nearest to yoğunluğu: yoğunluğunun, yoğunlukları, düşen, yoğunluk, yoğunluğunu, hesaplanır, yoğunluklarının, yoğunluğuna,
# Nearest to sınıf: sınıfları, sınıflar, öğrenci, öğrencilerin, sınıflarına, sınıfına, sınıfta, sınıfa,
# Epoch 15/15 Iteration: 227100 Avg. Training loss: 3.7334 0.0275 sec/batch
# Epoch 15/15 Iteration: 227200 Avg. Training loss: 3.7126 0.0253 sec/batch
# Epoch 15/15 Iteration: 227300 Avg. Training loss: 3.6350 0.0253 sec/batch
# Epoch 15/15 Iteration: 227400 Avg. Training loss: 3.6621 0.0251 sec/batch
# Epoch 15/15 Iteration: 227500 Avg. Training loss: 3.5249 0.0253 sec/batch
# Epoch 15/15 Iteration: 227600 Avg. Training loss: 3.6548 0.0252 sec/batch
# Epoch 15/15 Iteration: 227700 Avg. Training loss: 3.5672 0.0258 sec/batch
# Epoch 15/15 Iteration: 227800 Avg. Training loss: 3.5305 0.0256 sec/batch
# Epoch 15/15 Iteration: 227900 Avg. Training loss: 3.5964 0.0255 sec/batch
# Epoch 15/15 Iteration: 228000 Avg. Training loss: 3.5430 0.0255 sec/batch
# Nearest to used: been, out, evaluated, carried, determine, are, according, by,
# Nearest to and: of, the, in, to, for, with, by, this,
# Nearest to göre: olarak, ile, ve, yapılan, edilmiştir, olduğu, düşük, verilmiştir,
# Nearest to f: a, b, c, s, k, r, g, d,
# Nearest to su: suyun, water, suyu, sulama, aşağı, suya, baraj, kaynaklarının,
# Nearest to as: to, in, the, and, this, are, with, of,
# Nearest to daha: olduğu, ile, olarak, ve, yüksek, da, elde, önemli,
# Nearest to on: the, of, and, with, in, a, for, c,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerinin, görüntülerde, piksel, görüntüde, görüntüye,
# Nearest to assessment: environmental, evaluation, assessing, for, bodies, by, assess, ecological,
# Nearest to azalma: artış, artmış, artışa, arttığı, artışın, oranında, daha, azalmıştır,
# Nearest to etkisini: etkisi, yaptıkları, farklı, incelemek, çalışmada, etkisinin, belirlemişlerdir, belirtmişlerdir,
# Nearest to olur: edilir, olurlar, eder, gerçekleşir, oluşur, bulunur, görülür, artar,
# Nearest to activities: activity, enzyme, against, have, of, by, their, different,
# Nearest to yoğunluğu: yoğunluğunun, yoğunlukları, düşen, yoğunluk, yoğunluğunu, sayısının, önemli, sayısını,
# Nearest to sınıf: sınıflar, sınıfları, sınıflarına, sınıfına, öğrencilerin, sınıfta, görmekte, başarımında,
# Epoch 15/15 Iteration: 228100 Avg. Training loss: 3.3193 0.0279 sec/batch
# Epoch 15/15 Iteration: 228200 Avg. Training loss: 3.7560 0.0257 sec/batch
# Epoch 15/15 Iteration: 228300 Avg. Training loss: 3.7077 0.0258 sec/batch
# Epoch 15/15 Iteration: 228400 Avg. Training loss: 3.6884 0.0254 sec/batch
# Epoch 15/15 Iteration: 228500 Avg. Training loss: 3.8050 0.0257 sec/batch
# Epoch 15/15 Iteration: 228600 Avg. Training loss: 3.6756 0.0254 sec/batch
# Epoch 15/15 Iteration: 228700 Avg. Training loss: 3.6201 0.0254 sec/batch
# Epoch 15/15 Iteration: 228800 Avg. Training loss: 3.7555 0.0255 sec/batch
# Epoch 15/15 Iteration: 228900 Avg. Training loss: 3.6658 0.0255 sec/batch
# Epoch 15/15 Iteration: 229000 Avg. Training loss: 3.7416 0.0254 sec/batch
# Nearest to used: been, are, the, was, were, by, evaluated, study,
# Nearest to and: in, of, the, with, for, by, to, as,
# Nearest to göre: olarak, ile, sonuçları, arasında, ve, tablo, edilmiştir, ise,
# Nearest to f: a, b, s, d, c, e, g, h,
# Nearest to su: suyun, suyu, water, suya, içme, baraj, kaynaklarının, gölü,
# Nearest to as: the, to, are, and, is, in, this, it,
# Nearest to daha: olduğu, ile, olduğunu, ve, yüksek, yapılan, olarak, elde,
# Nearest to on: the, with, in, of, and, a, to, for,
# Nearest to görüntü: görüntüler, görüntülerin, görüntünün, görüntülerinin, görüntülerde, piksel, görüntüleri, görüntüde,
# Nearest to assessment: environmental, assessing, evaluation, for, assess, ecological, bodies, and,
# Nearest to azalma: artış, artmış, artışa, arttığı, artışın, azalmıştır, artan, oranda,
# Nearest to etkisini: incelemişlerdir, etkisi, arkadaşları, incelemek, belirlemişlerdir, kullanarak, etkisinin, etkilediğini,
# Nearest to olur: eder, meydana, edilir, gelerek, olurlar, görülür, oluşur, bulunur,
# Nearest to activities: activity, enzyme, study, against, aktivitelerinin, different, it, have,
# Nearest to yoğunluğu: yoğunluğunun, düşen, yoğunlukları, yoğunluk, yoğunluğunu, yoğunluğuna, yoğunluğun, yoğunluklarının,
# Nearest to sınıf: öğrenci, öğrencilerin, eğitim, görmekte, sınıflar, sınıfları, sınıfta, sınıflarına,
# Epoch 15/15 Iteration: 229100 Avg. Training loss: 3.6070 0.0277 sec/batch
# Epoch 15/15 Iteration: 229200 Avg. Training loss: 3.5540 0.0255 sec/batch
# Epoch 15/15 Iteration: 229300 Avg. Training loss: 3.5255 0.0252 sec/batch
# Epoch 15/15 Iteration: 229400 Avg. Training loss: 3.6492 0.0254 sec/batch
# Epoch 15/15 Iteration: 229500 Avg. Training loss: 3.7239 0.0255 sec/batch
# Epoch 15/15 Iteration: 229600 Avg. Training loss: 3.7141 0.0254 sec/batch
# Epoch 15/15 Iteration: 229700 Avg. Training loss: 3.7022 0.0260 sec/batch
# Epoch 15/15 Iteration: 229800 Avg. Training loss: 3.7125 0.0260 sec/batch
# Epoch 15/15 Iteration: 229900 Avg. Training loss: 3.7192 0.0260 sec/batch
# Epoch 15/15 Iteration: 230000 Avg. Training loss: 3.6757 0.0261 sec/batch
# Nearest to used: the, are, been, in, by, was, were, for,
# Nearest to and: of, in, the, with, for, by, was, on,
# Nearest to göre: değerleri, ise, olarak, tablo, verilmiştir, ile, sonuçları, ve,
# Nearest to f: s, a, c, b, e, r, h, z,
# Nearest to su: suyun, suyu, suya, water, kaynaklarının, yardımıyla, basınç, miktarının,
# Nearest to as: to, the, are, it, and, this, in, is,
# Nearest to daha: yüksek, ve, de, elde, iki, ise, oranında, diğer,
# Nearest to on: of, with, the, and, in, effect, different, a,
# Nearest to görüntü: görüntülerin, görüntüler, görüntülerinin, görüntünün, piksel, görüntülerde, görüntüde, görüntüsü,
# Nearest to assessment: environmental, assessing, evaluation, bodies, for, of, assess, monitoring,
# Nearest to azalma: artış, oranında, artan, önemli, arttığı, bu, artışın, artışa,
# Nearest to etkisini: etkisi, ve, incelemişlerdir, benzer, belirlemişlerdir, bir, ile, çalışmalarında,
# Nearest to olur: eder, etkilemektedir, neden, edilir, bulunur, çıkışını, meydana, görülür,
# Nearest to activities: activity, against, and, by, enzyme, aktivitelerinin, of, the,
# Nearest to yoğunluğu: yoğunluğunun, yoğunlukları, düşen, yoğunluk, yoğunluğunu, yoğunluğuna, biridir, yoğunluğun,
# Nearest to sınıf: öğrenci, sınıflar, öğrencilerin, eğitim, görmekte, sınıfta, sınıfları, sınıflara,
# Epoch 15/15 Iteration: 230100 Avg. Training loss: 3.6649 0.0275 sec/batch
# Epoch 15/15 Iteration: 230200 Avg. Training loss: 3.5963 0.0253 sec/batch
# Epoch 15/15 Iteration: 230300 Avg. Training loss: 3.4940 0.0252 sec/batch
# Epoch 15/15 Iteration: 230400 Avg. Training loss: 3.6695 0.0252 sec/batch
# Epoch 15/15 Iteration: 230500 Avg. Training loss: 3.7363 0.0253 sec/batch
# Epoch 15/15 Iteration: 230600 Avg. Training loss: 3.7600 0.0253 sec/batch
