# %%
import tensorflow as tf

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
with open('C://kelimeler_dergipark.txt', encoding='utf-8') as f:
    text = f.read()

# %%
words = preprocess(text)

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 47871428
# Unique words: 276431

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
vocab_to_int

# %%
import numpy as np
import tensorflow as tf
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 21911256

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)
    
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
tf.compat.v1.disable_eager_execution()
with tf.Graph().as_default() as train_graph:
    inputs = tf.compat.v1.placeholder(tf.int32, [None], name='inputs')
    labels = tf.compat.v1.placeholder(tf.int32, [None, None], name='labels')

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random.uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.compat.v1.train.AdamOptimizer().minimize(cost)

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.math.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# !mkdir checkpoints

# %%
import time
epochs = 15
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.compat.v1.train.Saver()

with tf.compat.v1.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.compat.v1.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
        embed_mat = sess.run(normalized_embedding)

        with open('C://checkpoints//embedding_dergipark.txt', 'w') as file_:
            for i in range(n_vocab):
                embd = embed_mat[i, :]
                wrd = int_to_vocab[i]
                file_.write('%s %s\n' % (wrd, ' '.join(map(str, embd))))
# Out:
# Streaming output truncated to the last 5000 lines.
# Nearest to dışı: kkkkkk, telafi, değişkenlerini, agresif, kaynaklıdır, yükselşahin, httpwwwresulaytemurcomindexphpworks, rasekh,
# Epoch 7/15 Iteration: 136100 Avg. Training loss: 3.7137 0.0432 sec/batch
# Epoch 7/15 Iteration: 136200 Avg. Training loss: 3.8624 0.0387 sec/batch
# Epoch 7/15 Iteration: 136300 Avg. Training loss: 3.8866 0.0384 sec/batch
# Epoch 7/15 Iteration: 136400 Avg. Training loss: 3.7964 0.0385 sec/batch
# Epoch 7/15 Iteration: 136500 Avg. Training loss: 3.8248 0.0381 sec/batch
# Epoch 7/15 Iteration: 136600 Avg. Training loss: 3.8280 0.0383 sec/batch
# Epoch 7/15 Iteration: 136700 Avg. Training loss: 3.8703 0.0384 sec/batch
# Epoch 7/15 Iteration: 136800 Avg. Training loss: 3.8744 0.0384 sec/batch
# Epoch 7/15 Iteration: 136900 Avg. Training loss: 3.8364 0.0381 sec/batch
# Epoch 7/15 Iteration: 137000 Avg. Training loss: 3.7706 0.0384 sec/batch
# Nearest to olduğu: görülmektedir, ise, görülmüştür, bu, olarak, olan, daha, söylenebilir,
# Nearest to o: i̇, e, s, m, a, ilg, sıralayabiliriz, k,
# Nearest to h: s, a, c, m, ve, and, r, n,
# Nearest to c: s, m, a, h, l, and, g, d,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, tezi, yayınlanmamış, social, i̇ktisadi,
# Nearest to tarafından: olarak, geliştirilen, ve, bu, olan, geliştirilmiş, bir, ile,
# Nearest to yüksek: lisans, tezi, doktora, düşük, enstitüsü, olduğu, görülmektedir, üniversitesi,
# Nearest to edilen: elde, edilmiştir, ve, olarak, ile, için, edilmiş, eden,
# Nearest to parameters: objective, environmental, obtained, results, table, ağlamaklı, values, speed,
# Nearest to thus: since, deum, dönüşümlerin, sels, tne, then, zülfi̇kar, wallpaper,
# Nearest to toplumun: toplumsal, ölçütüdür, toplumunun, birey, milletin, toplumdaki, velfunn, mirenda,
# Nearest to und: erbatur, stemmer, allgemeine, klaus, erlebt, açıklayabilmesi, reciprocal, harveyin,
# Nearest to kurumu: kurumunun, terimleri, i̇statistik, ankara, sözlüğü, avcioğlu, sisteminde, arabulucuların,
# Nearest to kendisine: noktalar, ettiği, etmesi, emaneti, kendisini, kaybetmesinin, bloklarda, gerçekleştirme,
# Nearest to set: let, periyot, kübist, türetilmektedir, sets, agrawal, splines, asrm,
# Nearest to dışı: kkkkkk, değişkenlerini, telafi, agresif, yükselşahin, oranındadır, kaynaklıdır, httpwwwresulaytemurcomindexphpworks,
# Epoch 7/15 Iteration: 137100 Avg. Training loss: 3.7766 0.0430 sec/batch
# Epoch 7/15 Iteration: 137200 Avg. Training loss: 3.8511 0.0384 sec/batch
# Epoch 7/15 Iteration: 137300 Avg. Training loss: 3.6980 0.0383 sec/batch
# Epoch 7/15 Iteration: 137400 Avg. Training loss: 3.8444 0.0385 sec/batch
# Epoch 7/15 Iteration: 137500 Avg. Training loss: 3.8521 0.0384 sec/batch
# Epoch 7/15 Iteration: 137600 Avg. Training loss: 3.9278 0.0387 sec/batch
# Epoch 7/15 Iteration: 137700 Avg. Training loss: 3.7507 0.0384 sec/batch
# Epoch 7/15 Iteration: 137800 Avg. Training loss: 3.7642 0.0386 sec/batch
# Epoch 7/15 Iteration: 137900 Avg. Training loss: 3.8126 0.0387 sec/batch
# Epoch 7/15 Iteration: 138000 Avg. Training loss: 3.8567 0.0384 sec/batch
# Nearest to olduğu: ise, görülmektedir, görülmüştür, bir, olarak, daha, bu, edilmiştir,
# Nearest to o: i̇, s, e, ilg, m, a, sıralayabiliriz, k,
# Nearest to h: s, c, a, ve, m, r, b, and,
# Nearest to c: s, m, h, a, l, b, g, r,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, tezi, yayınlanmamış, social, yüksek,
# Nearest to tarafından: olarak, geliştirilen, geliştirilmiş, ve, bir, olan, bu, bulunmaktadır,
# Nearest to yüksek: lisans, tezi, düşük, daha, enstitüsü, doktora, görülmektedir, olduğu,
# Nearest to edilen: elde, edilmiştir, ile, ve, olarak, eden, olan, edildiği,
# Nearest to parameters: objective, environmental, table, values, vzı, ağlamaklı, speed, results,
# Nearest to thus: since, deum, also, zülfi̇kar, sels, otofajik, wallpaper, dönüşümlerin,
# Nearest to toplumun: birey, toplumsal, ölçütüdür, toplumunun, milletin, toplumda, toplumdaki, sevgisi,
# Nearest to und: erbatur, klaus, stemmer, allgemeine, açıklayabilmesi, erlebt, daniela, angew,
# Nearest to kurumu: terimleri, kurumunun, i̇statistik, sözlüğü, ankara, avcioğlu, arabulucuların, tdk,
# Nearest to kendisine: noktalar, etmesi, emaneti, bloklarda, kendisini, ettiği, gerçekleştirme, kaybetmesinin,
# Nearest to set: let, periyot, kübist, türetilmektedir, sets, agrawal, splines, asrm,
# Nearest to dışı: kkkkkk, telafi, değişkenlerini, agresif, kaynaklıdır, yükselşahin, httpwwwresulaytemurcomindexphpworks, oranındadır,
# Epoch 7/15 Iteration: 138100 Avg. Training loss: 3.7871 0.0433 sec/batch
# Epoch 7/15 Iteration: 138200 Avg. Training loss: 3.9060 0.0386 sec/batch
# Epoch 7/15 Iteration: 138300 Avg. Training loss: 3.7581 0.0386 sec/batch
# Epoch 7/15 Iteration: 138400 Avg. Training loss: 3.7919 0.0386 sec/batch
# Epoch 7/15 Iteration: 138500 Avg. Training loss: 3.8437 0.0386 sec/batch
# Epoch 7/15 Iteration: 138600 Avg. Training loss: 3.6991 0.0386 sec/batch
# Epoch 7/15 Iteration: 138700 Avg. Training loss: 3.8683 0.0387 sec/batch
# Epoch 7/15 Iteration: 138800 Avg. Training loss: 3.8276 0.0386 sec/batch
# Epoch 7/15 Iteration: 138900 Avg. Training loss: 3.9183 0.0385 sec/batch
# Epoch 7/15 Iteration: 139000 Avg. Training loss: 3.7709 0.0387 sec/batch
# Nearest to olduğu: görülmektedir, ise, görülmüştür, daha, edilmiştir, bir, olarak, olmadığı,
# Nearest to o: i̇, e, ilg, s, m, a, sıralayabiliriz, ll,
# Nearest to h: s, c, a, m, r, and, n, b,
# Nearest to c: m, s, l, a, h, and, g, d,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, yayınlanmamış, i̇ktisadi, tezi,
# Nearest to tarafından: geliştirilen, olarak, geliştirilmiş, ve, bu, olan, için, bir,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, daha, üniversitesi, sahip,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, için, olan, eden,
# Nearest to parameters: objective, environmental, table, ağlamaklı, sünnetine, vzı, parameter, temtek,
# Nearest to thus: since, that, deum, tne, dönüşümlerin, also, have, zülfi̇kar,
# Nearest to toplumun: birey, toplumsal, toplumunun, ölçütüdür, toplumdaki, toplumda, i̇nsanların, milletin,
# Nearest to und: erbatur, allgemeine, eine, erlebt, klaus, stemmer, daniela, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, avcioğlu, arabulucuların, tdk,
# Nearest to kendisine: kendisini, etmesi, bloklarda, gerçekleştirme, emaneti, kaybetmesinin, yonlar, noktalar,
# Nearest to set: let, periyot, türetilmektedir, kübist, sets, agrawal, kitlesinin, fuzzy,
# Nearest to dışı: kkkkkk, değişkenlerini, telafi, kaynaklıdır, yükselşahin, httpwwwresulaytemurcomindexphpworks, agresif, ebyslerde,
# Epoch 7/15 Iteration: 139100 Avg. Training loss: 3.9075 0.0435 sec/batch
# Epoch 7/15 Iteration: 139200 Avg. Training loss: 3.8396 0.0385 sec/batch
# Epoch 7/15 Iteration: 139300 Avg. Training loss: 3.7848 0.0389 sec/batch
# Epoch 7/15 Iteration: 139400 Avg. Training loss: 3.8049 0.0388 sec/batch
# Epoch 7/15 Iteration: 139500 Avg. Training loss: 3.9029 0.0388 sec/batch
# Epoch 7/15 Iteration: 139600 Avg. Training loss: 3.9245 0.0389 sec/batch
# Epoch 7/15 Iteration: 139700 Avg. Training loss: 3.7273 0.0392 sec/batch
# Epoch 7/15 Iteration: 139800 Avg. Training loss: 3.9039 0.0393 sec/batch
# Epoch 7/15 Iteration: 139900 Avg. Training loss: 3.7606 0.0395 sec/batch
# Epoch 7/15 Iteration: 140000 Avg. Training loss: 3.9424 0.0389 sec/batch
# Nearest to olduğu: görülmektedir, ise, daha, edilmiştir, görülmüştür, olarak, incelendiğinde, ayrıca,
# Nearest to o: i̇, e, a, s, m, ilg, k, sıralayabiliriz,
# Nearest to h: a, c, s, m, and, b, r, d,
# Nearest to c: s, m, a, l, h, and, b, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, yayınlanmamış, tezi, i̇ktisadi,
# Nearest to tarafından: olarak, geliştirilen, ve, olan, geliştirilmiş, bu, için, ile,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, üniversitesi, daha, sahip,
# Nearest to edilen: elde, edilmiştir, ile, ve, için, olarak, edildiği, olan,
# Nearest to parameters: objective, table, environmental, obtained, parameter, values, results, ağlamaklı,
# Nearest to thus: since, deum, otofajik, dönüşümlerin, transmembrane, zülfi̇kar, tne, dünyadır,
# Nearest to toplumun: toplumsal, birey, toplumunun, toplumdaki, ölçütüdür, insan, yararını, toplumda,
# Nearest to und: erbatur, allgemeine, klaus, eine, stemmer, erlebt, daniela, açıklayabilmesi,
# Nearest to kurumu: kurumunun, ankara, i̇statistik, terimleri, sözlüğü, avcioğlu, dona, bahaeddin,
# Nearest to kendisine: kendisini, etmesi, gerçekleştirme, kaybetmesinin, emaneti, bloklarda, noktalar, continuation,
# Nearest to set: periyot, let, türetilmektedir, kübist, agrawal, sets, splines, asrm,
# Nearest to dışı: kkkkkk, değişkenlerini, agresif, telafi, yükselşahin, kaynaklıdır, httpwwwresulaytemurcomindexphpworks, oranındadır,
# Epoch 7/15 Iteration: 140100 Avg. Training loss: 3.7227 0.0437 sec/batch
# Epoch 7/15 Iteration: 140200 Avg. Training loss: 3.8517 0.0388 sec/batch
# Epoch 7/15 Iteration: 140300 Avg. Training loss: 3.8783 0.0390 sec/batch
# Epoch 7/15 Iteration: 140400 Avg. Training loss: 3.9265 0.0389 sec/batch
# Epoch 7/15 Iteration: 140500 Avg. Training loss: 3.8056 0.0386 sec/batch
# Epoch 7/15 Iteration: 140600 Avg. Training loss: 3.7842 0.0387 sec/batch
# Epoch 7/15 Iteration: 140700 Avg. Training loss: 3.8794 0.0391 sec/batch
# Epoch 7/15 Iteration: 140800 Avg. Training loss: 3.8435 0.0389 sec/batch
# Epoch 7/15 Iteration: 140900 Avg. Training loss: 3.7191 0.0391 sec/batch
# Epoch 7/15 Iteration: 141000 Avg. Training loss: 3.6594 0.0391 sec/batch
# Nearest to olduğu: ise, görülmektedir, olarak, edilmiştir, da, bu, görülmüştür, bir,
# Nearest to o: i̇, e, a, m, s, ilg, ç, k,
# Nearest to h: a, c, s, m, and, r, d, g,
# Nearest to c: m, a, s, l, h, and, d, g,
# Nearest to sosyal: bilimler, enstitüsü, üniversitesi, dergisi, social, yayınlanmamış, i̇ktisadi, tezi,
# Nearest to tarafından: olarak, geliştirilen, olan, ve, bu, geliştirilmiş, için, ile,
# Nearest to yüksek: lisans, düşük, tezi, doktora, enstitüsü, daha, üniversitesi, olduğu,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, de, olan, ayrıca,
# Nearest to parameters: table, objective, ağlamaklı, obtained, parameter, environmental, results, hesaplamaya,
# Nearest to thus: since, deum, dönüşümlerin, zülfi̇kar, tne, by, otofajik, have,
# Nearest to toplumun: birey, toplumunun, ölçütüdür, toplumsal, toplumda, yararını, toplumdaki, yinelenmiş,
# Nearest to und: erbatur, eine, erlebt, klaus, bevölkerung, stemmer, allgemeine, zentrale,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, avcioğlu, bahaeddin, türk,
# Nearest to kendisine: kendisini, etmesi, gerçekleştirme, kaybetmesinin, bloklarda, possi, continuation, emaneti,
# Nearest to set: let, periyot, sets, kübist, türetilmektedir, fuzzy, agrawal, splines,
# Nearest to dışı: kkkkkk, kaynaklıdır, telafi, agresif, httpwwwresulaytemurcomindexphpworks, yükselşahin, değişkenlerini, oranındadır,
# Epoch 7/15 Iteration: 141100 Avg. Training loss: 3.6048 0.0436 sec/batch
# Epoch 7/15 Iteration: 141200 Avg. Training loss: 3.6984 0.0389 sec/batch
# Epoch 7/15 Iteration: 141300 Avg. Training loss: 3.8187 0.0389 sec/batch
# Epoch 7/15 Iteration: 141400 Avg. Training loss: 3.8685 0.0390 sec/batch
# Epoch 7/15 Iteration: 141500 Avg. Training loss: 3.9207 0.0389 sec/batch
# Epoch 7/15 Iteration: 141600 Avg. Training loss: 3.9125 0.0389 sec/batch
# Epoch 7/15 Iteration: 141700 Avg. Training loss: 3.8612 0.0386 sec/batch
# Epoch 7/15 Iteration: 141800 Avg. Training loss: 3.8690 0.0390 sec/batch
# Epoch 7/15 Iteration: 141900 Avg. Training loss: 3.8144 0.0390 sec/batch
# Epoch 7/15 Iteration: 142000 Avg. Training loss: 3.5362 0.0389 sec/batch
# Nearest to olduğu: görülmektedir, ise, olmadığı, olarak, söylenebilir, görülmüştür, da, bu,
# Nearest to o: i̇, e, s, a, m, ilg, ç, k,
# Nearest to h: s, a, c, m, and, r, b, g,
# Nearest to c: s, m, a, h, l, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, yayınlanmamış, tezi, araştırmalar,
# Nearest to tarafından: olarak, geliştirilen, olan, geliştirilmiş, ve, bu, diğer, için,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, üniversitesi, sahip, daha,
# Nearest to edilen: elde, edilmiştir, ve, ile, olan, olarak, için, ise,
# Nearest to parameters: objective, table, environmental, obtained, ağlamaklı, values, dından, parameter,
# Nearest to thus: since, tne, deum, transmembrane, dönüşümlerin, zülfi̇kar, otofajik, wallpaper,
# Nearest to toplumun: birey, toplumunun, toplumsal, ölçütüdür, toplumda, yararını, ahlaklı, topluma,
# Nearest to und: erbatur, eine, allgemeine, erlebt, bevölkerung, zentrale, stemmer, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, avcioğlu, sisteminde, arabulucuların,
# Nearest to kendisine: etmesi, kendisini, gerçekleştirme, ettiği, theodoraki, kaybetmesinin, lawyers, noktalar,
# Nearest to set: let, periyot, sets, türetilmektedir, kübist, agrawal, fuzzy, splines,
# Nearest to dışı: kaynaklıdır, httpwwwresulaytemurcomindexphpworks, kkkkkk, değişkenlerini, telafi, agresif, yükselşahin, ebyslerde,
# Epoch 7/15 Iteration: 142100 Avg. Training loss: 3.9080 0.0436 sec/batch
# Epoch 7/15 Iteration: 142200 Avg. Training loss: 3.8327 0.0388 sec/batch
# Epoch 7/15 Iteration: 142300 Avg. Training loss: 2.6186 0.0390 sec/batch
# Epoch 7/15 Iteration: 142400 Avg. Training loss: 3.7822 0.0388 sec/batch
# Epoch 7/15 Iteration: 142500 Avg. Training loss: 3.8608 0.0388 sec/batch
# Epoch 7/15 Iteration: 142600 Avg. Training loss: 3.8152 0.0388 sec/batch
# Epoch 7/15 Iteration: 142700 Avg. Training loss: 3.7480 0.0386 sec/batch
# Epoch 7/15 Iteration: 142800 Avg. Training loss: 3.8114 0.0388 sec/batch
# Epoch 7/15 Iteration: 142900 Avg. Training loss: 3.9477 0.0386 sec/batch
# Epoch 7/15 Iteration: 143000 Avg. Training loss: 3.7874 0.0390 sec/batch
# Nearest to olduğu: görülmektedir, bu, ise, olarak, da, edilmiştir, görülmüştür, olan,
# Nearest to o: i̇, e, s, m, a, ç, ilg, k,
# Nearest to h: s, c, a, m, and, g, d, ve,
# Nearest to c: m, s, a, h, l, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, araştırmalar, yayınlanmamış, tezi,
# Nearest to tarafından: olarak, geliştirilen, olan, geliştirilmiş, diğer, bu, ve, için,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, üniversitesi, daha, sahip,
# Nearest to edilen: elde, edilmiştir, ve, olarak, ile, olan, ise, için,
# Nearest to parameters: objective, environmental, table, obtained, composition, infologica, parameter, ağlamaklı,
# Nearest to thus: deum, zülfi̇kar, dönüşümlerin, otofajik, transmembrane, since, have, that,
# Nearest to toplumun: birey, yararını, toplumunun, ölçütüdür, toplumsal, yinelenmiş, toplumda, toplumdaki,
# Nearest to und: erbatur, eine, allgemeine, bevölkerung, erlebt, stemmer, zentrale, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, avcioğlu, sisteminde, bahaeddin,
# Nearest to kendisine: etmesi, gerçekleştirme, eder, ettiği, bireyin, printmaking, kendisini, kendini,
# Nearest to set: let, periyot, sets, fuzzy, kübist, introduced, türetilmektedir, agrawal,
# Nearest to dışı: kkkkkk, yükselşahin, değişkenlerini, telafi, kaynaklıdır, agresif, tabi, httpwwwresulaytemurcomindexphpworks,
# Epoch 7/15 Iteration: 143100 Avg. Training loss: 3.8801 0.0434 sec/batch
# Epoch 7/15 Iteration: 143200 Avg. Training loss: 3.7984 0.0389 sec/batch
# Epoch 7/15 Iteration: 143300 Avg. Training loss: 3.8032 0.0387 sec/batch
# Epoch 7/15 Iteration: 143400 Avg. Training loss: 3.8065 0.0386 sec/batch
# Epoch 7/15 Iteration: 143500 Avg. Training loss: 3.8885 0.0388 sec/batch
# Epoch 7/15 Iteration: 143600 Avg. Training loss: 3.7619 0.0388 sec/batch
# Epoch 7/15 Iteration: 143700 Avg. Training loss: 3.7556 0.0387 sec/batch
# Epoch 7/15 Iteration: 143800 Avg. Training loss: 3.7975 0.0388 sec/batch
# Epoch 7/15 Iteration: 143900 Avg. Training loss: 3.6822 0.0386 sec/batch
# Epoch 7/15 Iteration: 144000 Avg. Training loss: 3.7846 0.0388 sec/batch
# Nearest to olduğu: görülmektedir, da, olarak, bir, ise, bu, diğer, daha,
# Nearest to o: i̇, e, s, m, a, ç, ilg, k,
# Nearest to h: s, a, c, m, and, r, g, b,
# Nearest to c: m, a, s, h, l, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, araştırmalar, yüksek, yayınlanmamış,
# Nearest to tarafından: olarak, geliştirilen, olan, geliştirilmiş, diğer, bu, ve, da,
# Nearest to yüksek: lisans, tezi, doktora, enstitüsü, düşük, üniversitesi, sahip, daha,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, olan, bu, ise,
# Nearest to parameters: objective, environmental, composition, infologica, temtek, owes, parameter, chem,
# Nearest to thus: result, since, deum, tne, dönüşümlerin, by, transmembrane, that,
# Nearest to toplumun: birey, ölçütüdür, toplumsal, toplumunun, yararını, toplumdaki, toplumda, optimüm,
# Nearest to und: erbatur, eine, allgemeine, erlebt, bevölkerung, zentrale, stemmer, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, i̇statistik, sözlüğü, avcioğlu, bahaeddin, sisteminde,
# Nearest to kendisine: etmesi, eder, ettiği, gerçekleştirme, bloklarda, noktalar, kaybetmesinin, emaneti,
# Nearest to set: let, sets, periyot, fuzzy, introduced, kübist, türetilmektedir, agrawal,
# Nearest to dışı: yükselşahin, değişkenlerini, telafi, kaynaklıdır, kkkkkk, httpwwwresulaytemurcomindexphpworks, tabi, ebyslerde,
# Epoch 7/15 Iteration: 144100 Avg. Training loss: 3.7798 0.0438 sec/batch
# Epoch 7/15 Iteration: 144200 Avg. Training loss: 3.8381 0.0390 sec/batch
# Epoch 7/15 Iteration: 144300 Avg. Training loss: 3.7448 0.0390 sec/batch
# Epoch 7/15 Iteration: 144400 Avg. Training loss: 2.6227 0.0390 sec/batch
# Epoch 7/15 Iteration: 144500 Avg. Training loss: 3.7704 0.0391 sec/batch
# Epoch 7/15 Iteration: 144600 Avg. Training loss: 3.7930 0.0389 sec/batch
# Epoch 7/15 Iteration: 144700 Avg. Training loss: 3.8753 0.0387 sec/batch
# Epoch 7/15 Iteration: 144800 Avg. Training loss: 3.7873 0.0388 sec/batch
# Epoch 7/15 Iteration: 144900 Avg. Training loss: 3.6397 0.0389 sec/batch
# Epoch 7/15 Iteration: 145000 Avg. Training loss: 3.7562 0.0390 sec/batch
# Nearest to olduğu: ise, görülmektedir, olarak, daha, edilmiştir, bu, diğer, incelendiğinde,
# Nearest to o: e, i̇, m, s, a, ilg, k, ll,
# Nearest to h: s, c, a, m, and, r, b, g,
# Nearest to c: s, m, h, a, l, d, and, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, tezi, araştırmalar, yayınlanmamış, social,
# Nearest to tarafından: olarak, olan, geliştirilen, bu, ve, geliştirilmiş, diğer, ile,
# Nearest to yüksek: lisans, tezi, düşük, enstitüsü, doktora, daha, sahip, olduğu,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, olan, için, ayrıca,
# Nearest to parameters: objective, composition, parameter, environmental, owes, chem, infologica, ağlamaklı,
# Nearest to thus: result, deum, dönüşümlerin, zülfi̇kar, kurmalarında, since, sels, nbyn,
# Nearest to toplumun: birey, toplumsal, toplumdaki, ölçütüdür, toplumunun, yararını, toplumda, yinelenmiş,
# Nearest to und: erbatur, allgemeine, erlebt, bevölkerung, eine, stemmer, zentrale, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, avcioğlu, arabulucuların, tdk,
# Nearest to kendisine: etmesi, ettiği, eder, noktalar, gerçekleştirme, bloklarda, emaneti, nassları,
# Nearest to set: let, sets, periyot, fuzzy, kübist, türetilmektedir, introduced, agrawal,
# Nearest to dışı: çeşitli, yükselşahin, telafi, agresif, kaynaklıdır, kkkkkk, değişkenlerini, nedeniyle,
# Epoch 7/15 Iteration: 145100 Avg. Training loss: 3.0195 0.0438 sec/batch
# Epoch 7/15 Iteration: 145200 Avg. Training loss: 3.5620 0.0388 sec/batch
# Epoch 7/15 Iteration: 145300 Avg. Training loss: 3.8117 0.0389 sec/batch
# Epoch 7/15 Iteration: 145400 Avg. Training loss: 3.9823 0.0389 sec/batch
# Epoch 7/15 Iteration: 145500 Avg. Training loss: 1.6345 0.0388 sec/batch
# Epoch 7/15 Iteration: 145600 Avg. Training loss: 2.7937 0.0390 sec/batch
# Epoch 7/15 Iteration: 145700 Avg. Training loss: 3.8189 0.0392 sec/batch
# Epoch 7/15 Iteration: 145800 Avg. Training loss: 3.8714 0.0394 sec/batch
# Epoch 7/15 Iteration: 145900 Avg. Training loss: 3.8792 0.0386 sec/batch
# Epoch 7/15 Iteration: 146000 Avg. Training loss: 3.8011 0.0386 sec/batch
# Nearest to olduğu: görülmektedir, daha, bu, olarak, diğer, ise, da, bir,
# Nearest to o: e, i̇, s, a, m, ilg, bir, k,
# Nearest to h: s, a, m, c, and, r, b, d,
# Nearest to c: s, m, a, l, h, d, and, g,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, social, araştırmalar, ve, ekonomik,
# Nearest to tarafından: olarak, olan, geliştirilen, bu, için, ve, ayrıca, birçok,
# Nearest to yüksek: lisans, düşük, tezi, daha, doktora, enstitüsü, olduğu, sahip,
# Nearest to edilen: elde, edilmiştir, ve, gibi, ile, ise, olan, olarak,
# Nearest to parameters: objective, composition, table, environmental, parameter, kalitesinin, infologica, temtek,
# Nearest to thus: result, since, dönüşümlerin, deum, zülfi̇kar, sels, kurmalarında, have,
# Nearest to toplumun: yararını, toplumsal, birey, toplumda, toplumdaki, yinelenmiş, toplumunun, ölçütüdür,
# Nearest to und: erbatur, allgemeine, erlebt, bevölkerung, zentrale, eine, stemmer, inandıklarını,
# Nearest to kurumu: kurumunun, terimleri, ankara, i̇statistik, sözlüğü, avcioğlu, tdk, arabulucuların,
# Nearest to kendisine: ettiği, etmesi, bloklarda, kendini, eder, gerçekleştirme, printmaking, kendisini,
# Nearest to set: let, sets, periyot, fuzzy, introduced, türetilmektedir, kübist, agrawal,
# Nearest to dışı: çeşitli, gibi, bazı, telafi, nedeniyle, alınan, agresif, yükselşahin,
# Epoch 7/15 Iteration: 146100 Avg. Training loss: 3.7279 0.0434 sec/batch
# Epoch 7/15 Iteration: 146200 Avg. Training loss: 3.8022 0.0387 sec/batch
# Epoch 7/15 Iteration: 146300 Avg. Training loss: 3.8090 0.0388 sec/batch
# Epoch 7/15 Iteration: 146400 Avg. Training loss: 3.7577 0.0390 sec/batch
# Epoch 7/15 Iteration: 146500 Avg. Training loss: 3.8251 0.0390 sec/batch
# Epoch 7/15 Iteration: 146600 Avg. Training loss: 3.6632 0.0390 sec/batch
# Epoch 7/15 Iteration: 146700 Avg. Training loss: 3.8424 0.0386 sec/batch
# Epoch 7/15 Iteration: 146800 Avg. Training loss: 3.6877 0.0390 sec/batch
# Epoch 7/15 Iteration: 146900 Avg. Training loss: 3.8576 0.0387 sec/batch
# Epoch 7/15 Iteration: 147000 Avg. Training loss: 3.8986 0.0388 sec/batch
# Nearest to olduğu: görülmektedir, daha, olarak, ise, olmadığı, da, bu, diğer,
# Nearest to o: e, i̇, s, m, bir, a, ilg, k,
# Nearest to h: a, s, c, m, and, r, b, d,
# Nearest to c: m, s, a, l, h, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, ve, araştırmalar, tezi,
# Nearest to tarafından: olarak, olan, geliştirilen, bu, ve, diğer, için, ise,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, daha, üniversitesi, olduğu,
# Nearest to edilen: elde, edilmiştir, ve, ile, olan, olarak, ise, edilmiş,
# Nearest to parameters: objective, composition, table, parameter, environmental, conditions, kalitesinin, variable,
# Nearest to thus: zülfi̇kar, kurmalarında, result, since, deum, transmembrane, sels, qext,
# Nearest to toplumun: birey, toplumsal, yararını, toplumunun, toplumdaki, toplumda, yinelenmiş, ölçütüdür,
# Nearest to und: erbatur, allgemeine, bevölkerung, erlebt, inandıklarını, linke, stemmer, eine,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, tdk, avcioğlu, arabulucuların,
# Nearest to kendisine: etmesi, ettiği, bloklarda, kendini, gerçekleştirme, printmaking, eder, noktalar,
# Nearest to set: let, sets, periyot, fuzzy, türetilmektedir, kübist, agrawal, introduced,
# Nearest to dışı: telafi, kkkkkk, yükselşahin, ebyslerde, çeşitli, agresif, nedeniyle, gibi,
# Epoch 7/15 Iteration: 147100 Avg. Training loss: 3.9134 0.0434 sec/batch
# Epoch 7/15 Iteration: 147200 Avg. Training loss: 3.8586 0.0389 sec/batch
# Epoch 7/15 Iteration: 147300 Avg. Training loss: 3.8688 0.0386 sec/batch
# Epoch 7/15 Iteration: 147400 Avg. Training loss: 3.9278 0.0388 sec/batch
# Epoch 7/15 Iteration: 147500 Avg. Training loss: 3.8505 0.0389 sec/batch
# Epoch 7/15 Iteration: 147600 Avg. Training loss: 3.7831 0.0389 sec/batch
# Epoch 7/15 Iteration: 147700 Avg. Training loss: 3.8850 0.0394 sec/batch
# Epoch 7/15 Iteration: 147800 Avg. Training loss: 3.8365 0.0395 sec/batch
# Epoch 7/15 Iteration: 147900 Avg. Training loss: 3.6799 0.0388 sec/batch
# Epoch 7/15 Iteration: 148000 Avg. Training loss: 3.7509 0.0387 sec/batch
# Nearest to olduğu: görülmektedir, olarak, bu, ise, daha, edilmiştir, diğer, ile,
# Nearest to o: e, a, i̇, s, m, k, ilg, bir,
# Nearest to h: c, s, a, m, and, r, b, d,
# Nearest to c: m, s, a, h, l, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, araştırmalar, tezi, yayınlanmamış,
# Nearest to tarafından: olarak, olan, bu, diğer, ve, için, ayrıca, geliştirilmiş,
# Nearest to yüksek: lisans, düşük, tezi, doktora, daha, olduğu, enstitüsü, sahip,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, olan, gibi, olduğu,
# Nearest to parameters: objective, table, parameter, composition, obtained, environmental, ağlamaklı, variable,
# Nearest to thus: zülfi̇kar, kurmalarında, transmembrane, sels, result, by, deum, since,
# Nearest to toplumun: birey, toplumsal, toplumunun, yararını, toplumdaki, toplumda, ölçütüdür, hamitin,
# Nearest to und: erbatur, allgemeine, bevölkerung, eine, erlebt, linke, daniela, supplementband,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, tdk, avcioğlu, yayınları,
# Nearest to kendisine: etmesi, ettiği, bloklarda, eder, printmaking, gerçekleştirme, emaneti, kendini,
# Nearest to set: let, periyot, sets, fuzzy, türetilmektedir, kübist, agrawal, introduced,
# Nearest to dışı: kkkkkk, telafi, gibi, vb, nedeniyle, httpwwwresulaytemurcomindexphpworks, bunlara, ebyslerde,
# Epoch 7/15 Iteration: 148100 Avg. Training loss: 3.8652 0.0438 sec/batch
# Epoch 7/15 Iteration: 148200 Avg. Training loss: 3.7178 0.0390 sec/batch
# Epoch 7/15 Iteration: 148300 Avg. Training loss: 3.8523 0.0387 sec/batch
# Epoch 7/15 Iteration: 148400 Avg. Training loss: 3.8651 0.0390 sec/batch
# Epoch 7/15 Iteration: 148500 Avg. Training loss: 3.8047 0.0389 sec/batch
# Epoch 7/15 Iteration: 148600 Avg. Training loss: 3.6396 0.0391 sec/batch
# Epoch 7/15 Iteration: 148700 Avg. Training loss: 3.8789 0.0388 sec/batch
# Epoch 7/15 Iteration: 148800 Avg. Training loss: 3.6988 0.0388 sec/batch
# Epoch 7/15 Iteration: 148900 Avg. Training loss: 3.9279 0.0389 sec/batch
# Epoch 7/15 Iteration: 149000 Avg. Training loss: 3.8170 0.0387 sec/batch
# Nearest to olduğu: olarak, bu, bir, olmadığı, görülmektedir, ve, da, ise,
# Nearest to o: i̇, e, a, m, k, s, ilg, ç,
# Nearest to h: c, s, a, and, m, r, b, d,
# Nearest to c: s, m, a, h, l, and, d, in,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, tezi, social, yayınlanmamış, araştırmalar,
# Nearest to tarafından: olarak, bu, olan, ve, diğer, da, de, geliştirilmiş,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, daha, olduğu, üniversitesi,
# Nearest to edilen: elde, edilmiştir, ve, ile, olarak, yapılmıştır, olan, veriler,
# Nearest to parameters: obtained, table, environmental, objective, composition, parameter, variable, ağlamaklı,
# Nearest to thus: zülfi̇kar, kurmalarında, by, transmembrane, sels, biyo, çekilmesinden, deum,
# Nearest to toplumun: toplumsal, yararını, toplumdaki, birey, toplumunun, ölçütüdür, toplumda, hamitin,
# Nearest to und: bevölkerung, erbatur, allgemeine, eine, elsuud, erlebt, linke, açıklayabilmesi,
# Nearest to kurumu: kurumunun, ankara, terimleri, sözlüğü, i̇statistik, tdk, türk, avcioğlu,
# Nearest to kendisine: etmesi, ettiği, bloklarda, eder, gerçekleştirme, emaneti, printmaking, noktalar,
# Nearest to set: let, sets, periyot, fuzzy, türetilmektedir, kübist, agrawal, introduced,
# Nearest to dışı: kkkkkk, gibi, telafi, bunlara, vb, httpwwwresulaytemurcomindexphpworks, ebyslerde, değişkenlerini,
# Epoch 7/15 Iteration: 149100 Avg. Training loss: 3.8198 0.0437 sec/batch
# Epoch 7/15 Iteration: 149200 Avg. Training loss: 3.9041 0.0387 sec/batch
# Epoch 7/15 Iteration: 149300 Avg. Training loss: 3.9062 0.0387 sec/batch
# Epoch 7/15 Iteration: 149400 Avg. Training loss: 3.9000 0.0386 sec/batch
# Epoch 7/15 Iteration: 149500 Avg. Training loss: 3.7549 0.0388 sec/batch
# Epoch 7/15 Iteration: 149600 Avg. Training loss: 3.8516 0.0390 sec/batch
# Epoch 7/15 Iteration: 149700 Avg. Training loss: 3.8779 0.0387 sec/batch
# Epoch 7/15 Iteration: 149800 Avg. Training loss: 3.8920 0.0386 sec/batch
# Epoch 7/15 Iteration: 149900 Avg. Training loss: 3.7522 0.0388 sec/batch
# Epoch 7/15 Iteration: 150000 Avg. Training loss: 3.9534 0.0386 sec/batch
# Nearest to olduğu: olarak, görülmektedir, olmadığı, ve, bu, bir, olan, önemli,
# Nearest to o: i̇, e, a, m, k, d, ç, s,
# Nearest to h: a, c, s, r, and, m, d, b,
# Nearest to c: s, m, a, h, and, l, d, for,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, social, yayınlanmamış, tezi, ve,
# Nearest to tarafından: olarak, olan, ve, bu, diğer, da, geliştirilmiş, de,
# Nearest to yüksek: tezi, lisans, düşük, doktora, daha, enstitüsü, olduğu, görülmektedir,
# Nearest to edilen: elde, ile, edilmiştir, ve, olarak, olan, kullanılarak, gibi,
# Nearest to parameters: objective, environmental, table, variable, temtek, httpsorcidorg, obtained, ağlamaklı,
# Nearest to thus: zülfi̇kar, kurmalarında, transmembrane, sels, pintor, biyo, also, deum,
# Nearest to toplumun: birey, toplumsal, yararını, toplumdaki, ölçütüdür, toplumunun, optimüm, yinelenmiş,
# Nearest to und: erbatur, bevölkerung, allgemeine, elsuud, eine, açıklayabilmesi, erlebt, linke,
# Nearest to kurumu: kurumunun, ankara, terimleri, sözlüğü, i̇statistik, tdk, yayınları, i,
# Nearest to kendisine: etmesi, bloklarda, ettiği, atılı, kendisini, eder, pestoff, printmaking,
# Nearest to set: let, sets, periyot, fuzzy, türetilmektedir, agrawal, kübist, introduced,
# Nearest to dışı: vb, kkkkkk, httpwwwresulaytemurcomindexphpworks, değişkenlerini, ebyslerde, yükselşahin, telafi, agresif,
# Epoch 7/15 Iteration: 150100 Avg. Training loss: 3.8977 0.0436 sec/batch
# Epoch 7/15 Iteration: 150200 Avg. Training loss: 3.8859 0.0388 sec/batch
# Epoch 7/15 Iteration: 150300 Avg. Training loss: 3.8672 0.0388 sec/batch
# Epoch 7/15 Iteration: 150400 Avg. Training loss: 3.9027 0.0390 sec/batch
# Epoch 7/15 Iteration: 150500 Avg. Training loss: 3.7645 0.0390 sec/batch
# Epoch 7/15 Iteration: 150600 Avg. Training loss: 3.5890 0.0391 sec/batch
# Epoch 7/15 Iteration: 150700 Avg. Training loss: 3.5305 0.0387 sec/batch
# Epoch 7/15 Iteration: 150800 Avg. Training loss: 3.7416 0.0384 sec/batch
# Epoch 7/15 Iteration: 150900 Avg. Training loss: 3.7635 0.0387 sec/batch
# Epoch 7/15 Iteration: 151000 Avg. Training loss: 3.7362 0.0389 sec/batch
# Nearest to olduğu: görülmektedir, olarak, olmadığı, bir, bu, da, diğer, ve,
# Nearest to o: i̇, e, a, m, s, k, ç, d,
# Nearest to h: a, s, c, m, and, r, d, g,
# Nearest to c: m, a, s, l, h, and, d, g,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, tezi, yayınlanmamış, yüksek, social,
# Nearest to tarafından: olarak, olan, diğer, bu, ve, geliştirilmiş, geliştirilen, da,
# Nearest to yüksek: tezi, lisans, düşük, enstitüsü, doktora, daha, olduğu, sahip,
# Nearest to edilen: elde, edilmiştir, ile, olarak, ve, kullanılarak, olan, sonuçlar,
# Nearest to parameters: objective, environmental, temtek, composition, ağlamaklı, sürdürür, httpsorcidorg, yağlık,
# Nearest to thus: zülfi̇kar, qanun, kurmalarında, transmembrane, also, pintor, sels, as,
# Nearest to toplumun: toplumsal, yararını, birey, ölçütüdür, toplumdaki, yinelenmiş, optimüm, eğitimden,
# Nearest to und: bevölkerung, eine, erbatur, allgemeine, erlebt, linke, supplementband, stemmer,
# Nearest to kurumu: kurumunun, terimleri, ankara, sözlüğü, i̇statistik, tdk, türk, yayınları,
# Nearest to kendisine: etmesi, bloklarda, ettiği, kendisini, atılı, emaneti, pestoff, eder,
# Nearest to set: let, periyot, sets, fuzzy, türetilmektedir, kübist, agrawal, ölçümlerde,
# Nearest to dışı: vb, değişkenlerini, httpwwwresulaytemurcomindexphpworks, kkkkkk, ebyslerde, telafi, yükselşahin, agresif,
# Epoch 7/15 Iteration: 151100 Avg. Training loss: 3.7567 0.0437 sec/batch
# Epoch 7/15 Iteration: 151200 Avg. Training loss: 3.6416 0.0387 sec/batch
# Epoch 7/15 Iteration: 151300 Avg. Training loss: 3.8449 0.0388 sec/batch
# Epoch 7/15 Iteration: 151400 Avg. Training loss: 3.8891 0.0389 sec/batch
# Epoch 7/15 Iteration: 151500 Avg. Training loss: 3.7670 0.0387 sec/batch
# Epoch 7/15 Iteration: 151600 Avg. Training loss: 3.7540 0.0387 sec/batch
# Epoch 7/15 Iteration: 151700 Avg. Training loss: 3.8697 0.0387 sec/batch
# Epoch 7/15 Iteration: 151800 Avg. Training loss: 3.8455 0.0383 sec/batch
# Epoch 7/15 Iteration: 151900 Avg. Training loss: 3.8999 0.0383 sec/batch
# Epoch 7/15 Iteration: 152000 Avg. Training loss: 3.7758 0.0386 sec/batch
# Nearest to olduğu: olarak, görülmektedir, ise, bu, söylenebilir, daha, olmadığı, diğer,
# Nearest to o: i̇, m, e, a, s, k, ç, d,
# Nearest to h: a, s, c, m, r, and, g, d,
# Nearest to c: s, m, a, h, l, and, d, b,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, yayınlanmamış, tezi, lisans, social,
# Nearest to tarafından: olarak, olan, bu, ve, geliştirilen, diğer, geliştirilmiş, için,
# Nearest to yüksek: düşük, tezi, lisans, doktora, olduğu, daha, enstitüsü, görülmektedir,
# Nearest to edilen: elde, ile, edilmiştir, ve, olarak, kullanılarak, sonuçlar, olan,
# Nearest to parameters: objective, environmental, ağlamaklı, temtek, values, obtained, composition, sürdürür,
# Nearest to thus: zülfi̇kar, kurmalarında, also, transmembrane, qanun, by, sels, wallpaper,
# Nearest to toplumun: toplumsal, yararını, ölçütüdür, toplumdaki, birey, toplumda, yinelenmiş, hamitin,
# Nearest to und: bevölkerung, eine, allgemeine, erbatur, erlebt, linke, açıklayabilmesi, daniela,
# Nearest to kurumu: kurumunun, ankara, terimleri, sözlüğü, i̇statistik, türk, tdk, avcioğlu,
# Nearest to kendisine: etmesi, bloklarda, ettiği, kendisini, pestoff, atılı, emaneti, eder,
# Nearest to set: let, periyot, sets, fuzzy, türetilmektedir, ölçümlerde, agrawal, kübist,
# Nearest to dışı: vb, değişkenlerini, httpwwwresulaytemurcomindexphpworks, telafi, ebyslerde, gibi, agresif, kkkkkk,
# Epoch 7/15 Iteration: 152100 Avg. Training loss: 3.8106 0.0433 sec/batch
# Epoch 7/15 Iteration: 152200 Avg. Training loss: 3.7033 0.0386 sec/batch
# Epoch 7/15 Iteration: 152300 Avg. Training loss: 3.9666 0.0385 sec/batch
# Epoch 7/15 Iteration: 152400 Avg. Training loss: 3.7629 0.0382 sec/batch
# Epoch 7/15 Iteration: 152500 Avg. Training loss: 3.8647 0.0385 sec/batch
# Epoch 7/15 Iteration: 152600 Avg. Training loss: 3.7588 0.0386 sec/batch
# Epoch 7/15 Iteration: 152700 Avg. Training loss: 3.8686 0.0386 sec/batch
# Epoch 7/15 Iteration: 152800 Avg. Training loss: 3.8703 0.0384 sec/batch
# Epoch 7/15 Iteration: 152900 Avg. Training loss: 3.9427 0.0383 sec/batch
# Epoch 7/15 Iteration: 153000 Avg. Training loss: 3.9553 0.0383 sec/batch
# Nearest to olduğu: olarak, görülmektedir, olmadığı, söylenebilir, daha, ise, bu, görülmüştür,
# Nearest to o: i̇, a, e, m, s, k, d, l,
# Nearest to h: a, s, c, m, and, d, r, g,
# Nearest to c: s, m, a, and, h, l, d, for,
# Nearest to sosyal: bilimler, dergisi, üniversitesi, enstitüsü, tezi, yayınlanmamış, lisans, yüksek,
# Nearest to tarafından: bu, olarak, ve, olan, diğer, için, ile, da,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, olduğu, daha, sahip,
# Nearest to edilen: elde, edilmiştir, ile, ve, olarak, bu, gibi, kullanılarak,
# Nearest to parameters: objective, environmental, ağlamaklı, temtek, values, parameter, composition, variable,
# Nearest to thus: that, zülfi̇kar, by, kurmalarında, qanun, also, gre, have,
# Nearest to toplumun: toplumsal, ölçütüdür, toplumdaki, yinelenmiş, birey, milletin, yararını, hamitin,
# Nearest to und: bevölkerung, eine, allgemeine, erbatur, erlebt, linke, stemmer, daniela,
# Nearest to kurumu: kurumunun, ankara, terimleri, i̇statistik, sözlüğü, tdk, yayınları, avcioğlu,
# Nearest to kendisine: etmesi, kendisini, bloklarda, atılı, ettiği, printmaking, kişiye, pestoff,
# Nearest to set: let, periyot, sets, fuzzy, agrawal, türetilmektedir, kübist, ölçümlerde,
# Nearest to dışı: değişkenlerini, httpwwwresulaytemurcomindexphpworks, vb, ebyslerde, nedeniyle, yükselşahin, kkkkkk, agresif,
# Epoch 7/15 Iteration: 153100 Avg. Training loss: 3.7799 0.0432 sec/batch
# Epoch 7/15 Iteration: 153200 Avg. Training loss: 3.8568 0.0381 sec/batch
# Epoch 7/15 Iteration: 153300 Avg. Training loss: 3.7965 0.0382 sec/batch
# Epoch 8/15 Iteration: 153400 Avg. Training loss: 3.8243 0.0106 sec/batch
# Epoch 8/15 Iteration: 153500 Avg. Training loss: 3.7227 0.0387 sec/batch
# Epoch 8/15 Iteration: 153600 Avg. Training loss: 3.6362 0.0396 sec/batch
# Epoch 8/15 Iteration: 153700 Avg. Training loss: 3.3036 0.0413 sec/batch
# Epoch 8/15 Iteration: 153800 Avg. Training loss: 3.7276 0.0396 sec/batch
# Epoch 8/15 Iteration: 153900 Avg. Training loss: 3.7041 0.0384 sec/batch
# Epoch 8/15 Iteration: 154000 Avg. Training loss: 3.4356 0.0386 sec/batch
# Nearest to olduğu: görülmektedir, söylenebilir, olarak, olmadığı, görülmüştür, daha, diğer, ise,
# Nearest to o: m, a, i̇, e, s, k, d, g,
# Nearest to h: a, c, s, and, m, d, of, with,
# Nearest to c: s, a, m, h, and, l, for, d,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, tezi, social, i̇ktisadi, yayınlanmamış,
# Nearest to tarafından: olarak, bu, ve, olan, geliştirilen, için, ayrıca, diğer,
# Nearest to yüksek: tezi, düşük, lisans, doktora, enstitüsü, olduğu, görülmektedir, sahip,
# Nearest to edilen: elde, edilmiştir, ile, olarak, ve, için, bu, olan,
# Nearest to parameters: objective, ağlamaklı, table, values, parameter, composition, environmental, variable,
# Nearest to thus: since, have, that, result, be, also, for, as,
# Nearest to toplumun: toplumsal, birey, ölçütüdür, yinelenmiş, milletin, toplumdaki, yararını, ahlaklı,
# Nearest to und: bevölkerung, eine, allgemeine, erbatur, linke, erlebt, angew, stemmer,
# Nearest to kurumu: kurumunun, ankara, terimleri, i̇statistik, sözlüğü, tdk, avcioğlu, türkiye,
# Nearest to kendisine: etmesi, atılı, kendisini, bloklarda, pestoff, printmaking, ettiği, possi,
# Nearest to set: let, sets, periyot, agrawal, fuzzy, türetilmektedir, kübist, splines,
# Nearest to dışı: değişkenlerini, nedeniyle, bırakılan, tabi, yükselşahin, httpwwwresulaytemurcomindexphpworks, vb, ve,
# Epoch 8/15 Iteration: 154100 Avg. Training loss: 3.6174 0.0430 sec/batch
# Epoch 8/15 Iteration: 154200 Avg. Training loss: 3.7398 0.0384 sec/batch
# Epoch 8/15 Iteration: 154300 Avg. Training loss: 3.8882 0.0383 sec/batch
# Epoch 8/15 Iteration: 154400 Avg. Training loss: 3.9435 0.0382 sec/batch
# Epoch 8/15 Iteration: 154500 Avg. Training loss: 3.7097 0.0383 sec/batch
# Epoch 8/15 Iteration: 154600 Avg. Training loss: 3.7481 0.0390 sec/batch
# Epoch 8/15 Iteration: 154700 Avg. Training loss: 3.6387 0.0389 sec/batch
# Epoch 8/15 Iteration: 154800 Avg. Training loss: 3.8631 0.0389 sec/batch
# Epoch 8/15 Iteration: 154900 Avg. Training loss: 3.7570 0.0380 sec/batch
# Epoch 8/15 Iteration: 155000 Avg. Training loss: 3.5554 0.0384 sec/batch
# Nearest to olduğu: görülmektedir, olmadığı, olarak, söylenebilir, ise, bu, edilmiştir, olan,
# Nearest to o: e, i̇, m, a, s, d, k, ç,
# Nearest to h: c, a, s, d, m, and, r, of,
# Nearest to c: s, m, a, and, h, l, d, in,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, tezi, social, yayınlanmamış, i̇ktisadi,
# Nearest to tarafından: olarak, geliştirilen, ve, ayrıca, için, bu, geliştirilmiş, olan,
# Nearest to yüksek: lisans, tezi, doktora, düşük, enstitüsü, daha, sahip, yayınlanmamış,
# Nearest to edilen: elde, edilmiştir, ile, ve, olarak, için, gibi, sonuçlar,
# Nearest to parameters: objective, values, ağlamaklı, parameter, environmental, table, variable, temtek,
# Nearest to thus: since, that, also, be, is, have, such, therefore,
# Nearest to toplumun: toplumsal, birey, ölçütüdür, yinelenmiş, toplumdaki, toplumda, milletin, kırmızıbiber,
# Nearest to und: allgemeine, bevölkerung, erbatur, eine, angew, linke, daniela, stemmer,
# Nearest to kurumu: kurumunun, ankara, i̇statistik, terimleri, sözlüğü, tdk, avcioğlu, sisteminde,
# Nearest to kendisine: etmesi, ettiği, kendisini, bloklarda, eder, etmiştir, atılı, kendine,
# Nearest to set: let, periyot, sets, fuzzy, kübist, türetilmektedir, agrawal, ölçümlerde,
# Nearest to dışı: değişkenlerini, yükselşahin, bırakılan, tabi, vb, akılcılık, kxk, telafi,
# Epoch 8/15 Iteration: 155100 Avg. Training loss: 3.9666 0.0431 sec/batch
# Epoch 8/15 Iteration: 155200 Avg. Training loss: 3.6864 0.0385 sec/batch
# Epoch 8/15 Iteration: 155300 Avg. Training loss: 3.7601 0.0386 sec/batch
# Epoch 8/15 Iteration: 155400 Avg. Training loss: 3.7547 0.0387 sec/batch
# Epoch 8/15 Iteration: 155500 Avg. Training loss: 3.7209 0.0384 sec/batch
# Epoch 8/15 Iteration: 155600 Avg. Training loss: 3.6706 0.0384 sec/batch
# Epoch 8/15 Iteration: 155700 Avg. Training loss: 3.5924 0.0386 sec/batch
# Epoch 8/15 Iteration: 155800 Avg. Training loss: 3.8331 0.0387 sec/batch
# Epoch 8/15 Iteration: 155900 Avg. Training loss: 3.6865 0.0386 sec/batch
# Epoch 8/15 Iteration: 156000 Avg. Training loss: 3.5368 0.0384 sec/batch
# Nearest to olduğu: görülmektedir, olarak, söylenebilir, ise, diğer, olmadığı, bu, bir,
# Nearest to o: e, i̇, m, a, s, k, ç, d,
# Nearest to h: c, a, s, d, m, and, r, g,
# Nearest to c: s, m, h, a, l, and, d, in,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, social, yayınlanmamış, tezi, yüksek,
# Nearest to tarafından: olarak, geliştirilen, ve, bu, diğer, geliştirilmiş, olan, edilmiştir,
# Nearest to yüksek: lisans, tezi, düşük, doktora, enstitüsü, sahip, olduğu, daha,
# Nearest to edilen: elde, edilmiştir, ile, olarak, ve, sonuçlar, olan, için,
# Nearest to parameters: objective, ağlamaklı, values, environmental, table, yağlık, temtek, kalitesinin,
# Nearest to thus: since, that, result, also, have, is, therefore, as,
# Nearest to toplumun: toplumsal, toplumdaki, birey, ölçütüdür, yinelenmiş, milletin, toplumda, optimüm,
# Nearest to und: allgemeine, bevölkerung, eine, linke, erlebt, angew, supplementband, brusellozlu,
# Nearest to kurumu: kurumunun, i̇statistik, ankara, terimleri, sözlüğü, girme, tdk, avcioğlu,
# Nearest to kendisine: etmesi, ettiği, kendisini, bloklarda, atılı, etmiştir, anbese, pestoff,
# Nearest to set: let, periyot, sets, kübist, türetilmektedir, agrawal, fuzzy, linki,
# Nearest to dışı: değişkenlerini, bırakılan, telafi, httpwwwresulaytemurcomindexphpworks, akılcılık, tabi, yükselşahin, agresif,
# Epoch 8/15 Iteration: 156100 Avg. Training loss: 3.8278 0.0430 sec/batch
# Epoch 8/15 Iteration: 156200 Avg. Training loss: 3.7220 0.0384 sec/batch
# Epoch 8/15 Iteration: 156300 Avg. Training loss: 3.8018 0.0380 sec/batch
# Epoch 8/15 Iteration: 156400 Avg. Training loss: 3.8526 0.0385 sec/batch
# Epoch 8/15 Iteration: 156500 Avg. Training loss: 3.8287 0.0387 sec/batch
# Epoch 8/15 Iteration: 156600 Avg. Training loss: 3.8412 0.0385 sec/batch
# Epoch 8/15 Iteration: 156700 Avg. Training loss: 3.8105 0.0383 sec/batch
# Epoch 8/15 Iteration: 156800 Avg. Training loss: 3.7421 0.0383 sec/batch
# Epoch 8/15 Iteration: 156900 Avg. Training loss: 3.7843 0.0384 sec/batch
# Epoch 8/15 Iteration: 157000 Avg. Training loss: 3.8380 0.0385 sec/batch
# Nearest to olduğu: görülmektedir, söylenebilir, olarak, ise, olmadığı, bu, ile, görülmüştür,
# Nearest to o: e, i̇, a, m, s, k, ilg, d,
# Nearest to h: c, a, s, d, m, r, and, b,
# Nearest to c: s, m, a, h, and, l, d, in,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, social, yayınlanmamış, örneği, lisans,
# Nearest to tarafından: geliştirilen, olarak, bu, ve, geliştirilmiş, bulunmaktadır, edilmiştir, da,
# Nearest to yüksek: lisans, düşük, tezi, doktora, enstitüsü, görülmektedir, sahip, olduğu,
# Nearest to edilen: elde, edilmiştir, ile, ve, olarak, olan, veriler, olduğu,
# Nearest to parameters: objective, ağlamaklı, values, environmental, table, obtained, yağlık, vzı,
# Nearest to thus: that, since, result, have, also, shows, as, is,
# Nearest to toplumun: toplumsal, ölçütüdür, toplumdaki, yinelenmiş, birey, toplumda, kırmızıbiber, optimüm,
# Nearest to und: allgemeine, bevölkerung, erlebt, eine, linke, supplementband, brusellozlu, reciprocal,
# Nearest to kurumu: kurumunun, i̇statistik, ankara, terimleri, sözlüğü, türkiye, tdk, girme,
# Nearest to kendisine: etmesi, ettiği, kendisini, atılı, bloklarda, kaybetmesinin, anbese, emaneti,
# Nearest to set: let, periyot, türetilmektedir, sets, kübist, agrawal, fuzzy, splines,
# Nearest to dışı: değişkenlerini, telafi, httpwwwresulaytemurcomindexphpworks, çeşitli, dışında, tutulmuştur, edilmiştir, tabi,
# Epoch 8/15 Iteration: 157100 Avg. Training loss: 3.8993 0.0434 sec/batch
# Epoch 8/15 Iteration: 157200 Avg. Training loss: 3.7674 0.0385 sec/batch
# Epoch 8/15 Iteration: 157300 Avg. Training loss: 3.6038 0.0384 sec/batch
# Epoch 8/15 Iteration: 157400 Avg. Training loss: 3.8041 0.0390 sec/batch
# Epoch 8/15 Iteration: 157500 Avg. Training loss: 3.8788 0.0395 sec/batch
# Epoch 8/15 Iteration: 157600 Avg. Training loss: 3.8803 0.0389 sec/batch
# Epoch 8/15 Iteration: 157700 Avg. Training loss: 3.8007 0.0391 sec/batch
# Epoch 8/15 Iteration: 157800 Avg. Training loss: 3.8676 0.0390 sec/batch
# Epoch 8/15 Iteration: 157900 Avg. Training loss: 3.6631 0.0390 sec/batch
# Epoch 8/15 Iteration: 158000 Avg. Training loss: 3.6791 0.0384 sec/batch
# Nearest to olduğu: görülmektedir, olarak, olan, söylenebilir, diğer, ise, olmadığı, bu,
# Nearest to o: e, i̇, s, m, a, k, sıralayabiliriz, ilg,
# Nearest to h: s, c, a, m, d, r, and, b,
# Nearest to c: s, m, a, and, h, l, d, b,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, yayınlanmamış, lisans, tezi, social,
# Nearest to tarafından: olarak, ve, geliştirilen, bu, bir, için, diğer, geliştirilmiş,
# Nearest to yüksek: düşük, lisans, tezi, enstitüsü, doktora, daha, görülmektedir, olduğu,
# Nearest to edilen: elde, edilmiştir, ile, olarak, ve, veriler, için, olan,
# Nearest to parameters: objective, environmental, obtained, kalitesinin, yağlık, values, sınırlarda, ağlamaklı,
# Nearest to thus: since, that, have, also, result, işıtman, shows, is,
# Nearest to toplumun: toplumsal, birey, toplumdaki, ölçütüdür, yinelenmiş, yayılıyor, kırmızıbiber, optimüm,
# Nearest to und: allgemeine, erlebt, bevölkerung, eine, linke, supplementband, fremden, brusellozlu,
# Nearest to kurumu: kurumunun, i̇statistik, terimleri, ankara, sözlüğü, avcioğlu, sisteminde, tdk,
# Nearest to kendisine: etmesi, kendisini, ettiği, atılı, anbese, printmaking, bloklarda, kaybetmesinin,
# Nearest to set: let, periyot, sets, türetilmektedir, fuzzy, agrawal, kübist, splines,
# Nearest to dışı: telafi, değişkenlerini, bırakılan, httpwwwresulaytemurcomindexphpworks, rasekh, düşünmekteydiler, wwwuyapgovtr, tabi,
# Epoch 8/15 Iteration: 158100 Avg. Training loss: 3.8826 0.0432 sec/batch
# Epoch 8/15 Iteration: 158200 Avg. Training loss: 3.9073 0.0384 sec/batch
# Epoch 8/15 Iteration: 158300 Avg. Training loss: 3.7783 0.0384 sec/batch
# Epoch 8/15 Iteration: 158400 Avg. Training loss: 3.7936 0.0385 sec/batch
# Epoch 8/15 Iteration: 158500 Avg. Training loss: 3.8524 0.0386 sec/batch
# Epoch 8/15 Iteration: 158600 Avg. Training loss: 3.8492 0.0381 sec/batch
# Epoch 8/15 Iteration: 158700 Avg. Training loss: 3.9283 0.0382 sec/batch
# Epoch 8/15 Iteration: 158800 Avg. Training loss: 3.8549 0.0383 sec/batch
# Epoch 8/15 Iteration: 158900 Avg. Training loss: 3.7380 0.0383 sec/batch
# Epoch 8/15 Iteration: 159000 Avg. Training loss: 3.8616 0.0383 sec/batch
# Nearest to olduğu: görülmektedir, söylenebilir, ise, olarak, görülmüştür, edilmiştir, bu, bir,
# Nearest to o: e, a, m, i̇, k, s, ç, sıralayabiliriz,
# Nearest to h: c, s, a, m, d, r, b, and,
# Nearest to c: s, m, a, h, and, d, b, l,
# Nearest to sosyal: bilimler, üniversitesi, dergisi, enstitüsü, social, tezi, yayınlanmamış, lisans,
# Nearest to tarafından: olarak, geliştirilen, ve, bu, için, üzere, bulunmaktadır, geliştirilmiş,
# Nearest to yüksek: düşük, lisans, tezi, enstitüsü, doktora, olduğu, daha, görülmektedir,
# Nearest to edilen: elde, edilmiştir, ile, veriler, olarak, ve, sonuçlar, için,
# Nearest to parameters: obtained, objective, values, table, environmental, chem, ağlamaklı, composition,
# Nearest to thus: since, that, have, shows, result, also, a, is,
# Nearest to toplumun: toplumsal, birey, ölçütüdür, toplumdaki, yinelenmiş, yararını, toplumunun, milletin,
# Nearest to und: bevölkerung, allgemeine, erlebt, eine, linke, supplementband, işılak, i̇ktisadın,
# Nearest to kurumu: kurumunun, terimleri, ankara, i̇statistik, sözlüğü, tdk, sisteminde, girme,
# ...
# Epoch 15/15 Iteration: 320600 Avg. Training loss: 4.0548 0.0383 sec/batch
# Epoch 15/15 Iteration: 320700 Avg. Training loss: 4.0229 0.0382 sec/batch
# Epoch 15/15 Iteration: 320800 Avg. Training loss: 1.3493 0.0385 sec/batch
# Epoch 15/15 Iteration: 320900 Avg. Training loss: 3.2078 0.0380 sec/batch
# Epoch 15/15 Iteration: 321000 Avg. Training loss: 3.9282 0.0382 sec/batch
# Nearest to olduğu: görülmektedir, ve, olan, edilmiştir, söylenebilir, bu, ise, ile,
# Nearest to o: e, m, d, a, r, k, i̇, n,
# Nearest to h: m, s, a, c, d, g, e, b,
# Nearest to c: d, s, g, m, a, e, and, h,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, yayınlanmamış, araştırmalar, tezi,
# Nearest to tarafından: olarak, olan, ve, ayrıca, için, bir, gibi, edilmektedir,
# Nearest to yüksek: düşük, lisans, tezi, daha, doktora, enstitüsü, ve, görülmüştür,
# Nearest to edilen: elde, edilmiştir, ve, arasında, ile, olan, ise, gibi,
# Nearest to parameters: parameter, parametrelerin, results, biochemical, and, in, table, parametreleri,
# Nearest to thus: since, is, as, therefore, have, that, the, such,
# Nearest to toplumun: değerine, topluma, toplum, beklentilerini, toplumdaki, anlaşılabilir, ihtiyaçlarını, toplumda,
# Nearest to und: zu, eine, zur, auf, für, zum, durch, nach,
# Nearest to kurumu: kurumunun, ankara, basımevi, tdk, i̇statistik, yayınları, kurumuna, sisteminde,
# Nearest to kendisine: kritik, konumu, ona, bir, etmektedir, ederek, bulunurken, konumundaki,
# Nearest to set: sets, called, definition, denoted, introduced, then, let, fuzzy,
# Nearest to dışı: bunlara, uygulanmıştır, uygulanmış, ise, kapsamında, gibi, aldığı, çeşitli,
# Epoch 15/15 Iteration: 321100 Avg. Training loss: 4.1178 0.0434 sec/batch
# Epoch 15/15 Iteration: 321200 Avg. Training loss: 3.9932 0.0384 sec/batch
# Epoch 15/15 Iteration: 321300 Avg. Training loss: 3.9461 0.0382 sec/batch
# Epoch 15/15 Iteration: 321400 Avg. Training loss: 3.9124 0.0384 sec/batch
# Epoch 15/15 Iteration: 321500 Avg. Training loss: 4.0134 0.0382 sec/batch
# Epoch 15/15 Iteration: 321600 Avg. Training loss: 3.9831 0.0383 sec/batch
# Epoch 15/15 Iteration: 321700 Avg. Training loss: 3.9678 0.0385 sec/batch
# Epoch 15/15 Iteration: 321800 Avg. Training loss: 4.0029 0.0385 sec/batch
# Epoch 15/15 Iteration: 321900 Avg. Training loss: 3.9077 0.0383 sec/batch
# Epoch 15/15 Iteration: 322000 Avg. Training loss: 3.8856 0.0381 sec/batch
# Nearest to olduğu: görülmektedir, olmadığı, söylenebilir, görülmüştür, edilmiştir, ile, ve, bu,
# Nearest to o: e, m, a, s, r, d, k, bir,
# Nearest to h: m, s, e, a, d, r, c, g,
# Nearest to c: d, g, s, m, a, b, h, e,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, doktora, araştırmalar, lisans, yayınlanmamış,
# Nearest to tarafından: olan, olarak, ve, geliştirilen, ayrıca, edilmektedir, ise, bu,
# Nearest to yüksek: tezi, lisans, doktora, düşük, enstitüsü, yayımlanmamış, daha, üniversitesi,
# Nearest to edilen: elde, edilmiştir, ile, edilmiş, ve, için, olan, arasında,
# Nearest to parameters: parameter, parametrelerin, biochemical, parametreleri, table, results, shown, study,
# Nearest to thus: therefore, is, have, as, since, to, result, the,
# Nearest to toplumun: değerine, topluma, toplumdaki, toplumda, beklentilerini, anlaşılabilir, toplum, toplumsal,
# Nearest to und: zu, zur, auf, eine, zum, durch, für, nach,
# Nearest to kurumu: kurumunun, ankara, basımevi, i̇statistik, yayınları, sisteminde, tdk, kurumuna,
# Nearest to kendisine: eder, kendisi, kendisini, bir, ona, onu, onun, yani,
# Nearest to set: sets, called, denoted, definition, introduced, let, fuzzy, intersection,
# Nearest to dışı: uygulanmıştır, uygulanmış, bunlara, kapsamında, olmayan, ise, tutulmuştur, vb,
# Epoch 15/15 Iteration: 322100 Avg. Training loss: 3.9126 0.0428 sec/batch
# Epoch 15/15 Iteration: 322200 Avg. Training loss: 4.0851 0.0381 sec/batch
# Epoch 15/15 Iteration: 322300 Avg. Training loss: 4.0300 0.0391 sec/batch
# Epoch 15/15 Iteration: 322400 Avg. Training loss: 4.0785 0.0390 sec/batch
# Epoch 15/15 Iteration: 322500 Avg. Training loss: 4.1045 0.0388 sec/batch
# Epoch 15/15 Iteration: 322600 Avg. Training loss: 4.0016 0.0381 sec/batch
# Epoch 15/15 Iteration: 322700 Avg. Training loss: 4.1037 0.0382 sec/batch
# Epoch 15/15 Iteration: 322800 Avg. Training loss: 4.1235 0.0384 sec/batch
# Epoch 15/15 Iteration: 322900 Avg. Training loss: 3.9564 0.0382 sec/batch
# Epoch 15/15 Iteration: 323000 Avg. Training loss: 3.9794 0.0382 sec/batch
# Nearest to olduğu: söylenebilir, görülmektedir, ise, anlaşılmaktadır, bu, olmadığı, da, edilmiştir,
# Nearest to o: e, m, a, d, g, r, b, i̇,
# Nearest to h: a, m, b, c, d, g, e, r,
# Nearest to c: s, d, m, g, a, e, b, h,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, social, doktora, yayınlanmamış, araştırmalar,
# Nearest to tarafından: olarak, ve, bir, olan, diğer, edilmektedir, için, edildiği,
# Nearest to yüksek: tezi, lisans, doktora, düşük, enstitüsü, yayımlanmamış, daha, görülmüştür,
# Nearest to edilen: elde, edilmiştir, ile, olarak, edilmiş, ve, arasında, bu,
# Nearest to parameters: parameter, parametrelerin, results, parametreleri, shown, biochemical, obtained, evaluate,
# Nearest to thus: therefore, have, since, result, such, is, as, that,
# Nearest to toplumun: topluma, toplumdaki, toplumda, değerine, birey, önemlisi, beklentilerini, milletin,
# Nearest to und: zur, zu, verlag, auf, aus, des, für, zum,
# Nearest to kurumu: kurumunun, ankara, basımevi, yayınları, i̇statistik, sisteminde, tdk, tarihi,
# Nearest to kendisine: bir, eder, verdiği, verilen, verir, buna, ederek, ona,
# Nearest to set: sets, called, denoted, definition, introduced, fuzzy, let, intersection,
# Nearest to dışı: uygulanmış, nedeniyle, kapsamında, olmayan, bunlara, uygulanmıştır, tutulmuştur, veya,
# Epoch 15/15 Iteration: 323100 Avg. Training loss: 3.9684 0.0431 sec/batch
# Epoch 15/15 Iteration: 323200 Avg. Training loss: 3.8799 0.0383 sec/batch
# Epoch 15/15 Iteration: 323300 Avg. Training loss: 3.8632 0.0385 sec/batch
# Epoch 15/15 Iteration: 323400 Avg. Training loss: 4.0786 0.0382 sec/batch
# Epoch 15/15 Iteration: 323500 Avg. Training loss: 3.8652 0.0384 sec/batch
# Epoch 15/15 Iteration: 323600 Avg. Training loss: 3.9450 0.0384 sec/batch
# Epoch 15/15 Iteration: 323700 Avg. Training loss: 4.0594 0.0383 sec/batch
# Epoch 15/15 Iteration: 323800 Avg. Training loss: 3.8471 0.0387 sec/batch
# Epoch 15/15 Iteration: 323900 Avg. Training loss: 3.8750 0.0385 sec/batch
# Epoch 15/15 Iteration: 324000 Avg. Training loss: 4.0571 0.0383 sec/batch
# Nearest to olduğu: ise, bir, söylenebilir, da, ile, bu, edilmiştir, görülmektedir,
# Nearest to o: e, a, m, d, r, g, i̇, k,
# Nearest to h: c, a, m, d, g, e, r, b,
# Nearest to c: s, m, d, g, a, h, e, b,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, doktora, tezi, social, yayınlanmamış,
# Nearest to tarafından: olarak, ve, edilmektedir, da, olan, için, bu, ayrıca,
# Nearest to yüksek: tezi, doktora, lisans, enstitüsü, yayımlanmamış, düşük, yayınlanmamış, daha,
# Nearest to edilen: elde, edilmiştir, ile, edilmiş, ve, olarak, için, arasında,
# Nearest to parameters: parameter, results, parametrelerin, shown, parametreleri, table, investigated, using,
# Nearest to thus: therefore, since, have, to, such, also, for, which,
# Nearest to toplumun: topluma, toplumda, toplumdaki, değerlerin, kültürün, toplum, social, bader,
# Nearest to und: zur, für, des, zu, eine, zum, von, auf,
# Nearest to kurumu: kurumunun, ankara, basımevi, yayınları, i̇statistik, sisteminde, tarihi, tdk,
# Nearest to kendisine: eder, ettiği, bulunması, kişiye, ederek, kendisini, etmesi, kendisinin,
# Nearest to set: sets, denoted, called, definition, introduced, fuzzy, let, intersection,
# Nearest to dışı: olmayan, uygulanmış, içi, alınmış, kapsamında, bunlara, veya, ise,
# Epoch 15/15 Iteration: 324100 Avg. Training loss: 3.9471 0.0429 sec/batch
# Epoch 15/15 Iteration: 324200 Avg. Training loss: 4.0044 0.0382 sec/batch
# Epoch 15/15 Iteration: 324300 Avg. Training loss: 4.0350 0.0384 sec/batch
# Epoch 15/15 Iteration: 324400 Avg. Training loss: 4.0230 0.0383 sec/batch
# Epoch 15/15 Iteration: 324500 Avg. Training loss: 4.0094 0.0381 sec/batch
# Epoch 15/15 Iteration: 324600 Avg. Training loss: 4.1601 0.0381 sec/batch
# Epoch 15/15 Iteration: 324700 Avg. Training loss: 4.0761 0.0382 sec/batch
# Epoch 15/15 Iteration: 324800 Avg. Training loss: 3.8982 0.0384 sec/batch
# Epoch 15/15 Iteration: 324900 Avg. Training loss: 4.0151 0.0382 sec/batch
# Epoch 15/15 Iteration: 325000 Avg. Training loss: 4.0756 0.0384 sec/batch
# Nearest to olduğu: söylenebilir, görülmektedir, ve, bu, olarak, edilmiştir, bir, olan,
# Nearest to o: e, a, m, d, r, i̇, k, n,
# Nearest to h: a, m, d, c, g, e, b, t,
# Nearest to c: s, d, a, m, h, g, b, and,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, ve, doktora, araştırmalar, social,
# Nearest to tarafından: ve, olarak, da, ile, bir, olan, diğer, ayrıca,
# Nearest to yüksek: tezi, doktora, düşük, lisans, enstitüsü, daha, göre, yayımlanmamış,
# Nearest to edilen: elde, edilmiştir, ile, edilmiş, ve, yapılan, olarak, olduğu,
# Nearest to parameters: parameter, results, investigated, shown, table, using, parametrelerin, obtained,
# Nearest to thus: therefore, have, since, to, first, as, which, such,
# Nearest to toplumun: topluma, kültürün, toplumdaki, toplumda, değerlerin, toplum, değerine, birey,
# Nearest to und: zur, zu, für, eine, zum, aus, auf, über,
# Nearest to kurumu: kurumunun, ankara, basımevi, yayınları, i̇statistik, tarihi, tdk, sözlüğü,
# Nearest to kendisine: ona, ettiği, kendisini, eder, kişiye, kendisinin, bir, onu,
# Nearest to set: sets, definition, called, denoted, let, fuzzy, then, introduced,
# Nearest to dışı: olmayan, uygulanmış, içi, nedeniyle, alınmış, gibi, uygulanmıştır, ise,
# Epoch 15/15 Iteration: 325100 Avg. Training loss: 4.0783 0.0431 sec/batch
# Epoch 15/15 Iteration: 325200 Avg. Training loss: 3.9161 0.0383 sec/batch
# Epoch 15/15 Iteration: 325300 Avg. Training loss: 4.1652 0.0382 sec/batch
# Epoch 15/15 Iteration: 325400 Avg. Training loss: 4.0170 0.0383 sec/batch
# Epoch 15/15 Iteration: 325500 Avg. Training loss: 4.0758 0.0384 sec/batch
# Epoch 15/15 Iteration: 325600 Avg. Training loss: 4.0220 0.0386 sec/batch
# Epoch 15/15 Iteration: 325700 Avg. Training loss: 4.0269 0.0385 sec/batch
# Epoch 15/15 Iteration: 325800 Avg. Training loss: 3.8699 0.0385 sec/batch
# Epoch 15/15 Iteration: 325900 Avg. Training loss: 3.8679 0.0386 sec/batch
# Epoch 15/15 Iteration: 326000 Avg. Training loss: 3.5696 0.0385 sec/batch
# Nearest to olduğu: görülmektedir, olan, ise, ile, da, ve, söylenebilir, bir,
# Nearest to o: e, a, m, d, r, g, i̇, y,
# Nearest to h: a, m, g, d, c, r, s, b,
# Nearest to c: s, d, m, a, g, h, b, l,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, yayınlanmamış, araştırmalar, doktora, lisans,
# Nearest to tarafından: olan, olarak, ve, ile, geliştirilmiş, da, edilmektedir, diğer,
# Nearest to yüksek: tezi, doktora, düşük, lisans, enstitüsü, yayımlanmamış, daha, yayınlanmamış,
# Nearest to edilen: elde, edilmiştir, ile, olarak, olan, edilmiş, kullanılarak, ve,
# Nearest to parameters: parameter, parametreleri, parametrelerin, table, investigated, shown, biochemical, results,
# Nearest to thus: have, as, such, since, which, therefore, where, to,
# Nearest to toplumun: topluma, değerlerin, toplumsal, toplumda, toplumdaki, kültürün, milletin, birey,
# Nearest to und: zur, für, zu, zum, eine, auf, aus, das,
# Nearest to kurumu: ankara, kurumunun, yayınları, basımevi, sözlüğü, dil, türk, tdk,
# Nearest to kendisine: kendisinin, kendisini, ettiği, verdiği, ona, kişiye, eder, vermesi,
# Nearest to set: sets, denoted, definition, fuzzy, introduced, let, called, then,
# Nearest to dışı: içi, uygulanmış, gibi, bunlara, uygulanmıştır, nedeniyle, alınmıştır, ve,
# Epoch 15/15 Iteration: 326100 Avg. Training loss: 3.9021 0.0429 sec/batch
# Epoch 15/15 Iteration: 326200 Avg. Training loss: 3.9857 0.0383 sec/batch
# Epoch 15/15 Iteration: 326300 Avg. Training loss: 3.8286 0.0383 sec/batch
# Epoch 15/15 Iteration: 326400 Avg. Training loss: 3.8690 0.0383 sec/batch
# Epoch 15/15 Iteration: 326500 Avg. Training loss: 3.8473 0.0382 sec/batch
# Epoch 15/15 Iteration: 326600 Avg. Training loss: 4.0503 0.0384 sec/batch
# Epoch 15/15 Iteration: 326700 Avg. Training loss: 4.0060 0.0383 sec/batch
# Epoch 15/15 Iteration: 326800 Avg. Training loss: 3.9403 0.0383 sec/batch
# Epoch 15/15 Iteration: 326900 Avg. Training loss: 3.8878 0.0381 sec/batch
# Epoch 15/15 Iteration: 327000 Avg. Training loss: 4.0257 0.0382 sec/batch
# Nearest to olduğu: görülmektedir, söylenebilir, diğer, olarak, bu, ettiği, görülmüştür, ise,
# Nearest to o: m, e, a, d, g, r, s, k,
# Nearest to h: l, g, a, m, s, d, ampamp, b,
# Nearest to c: s, d, m, a, g, r, and, b,
# Nearest to sosyal: bilimler, üniversitesi, enstitüsü, dergisi, tezi, yayınlanmamış, doktora, lisans,
# Nearest to tarafından: ve, olan, olarak, da, bir, bu, ayrıca, için,
# Nearest to yüksek: tezi, düşük, lisans, doktora, enstitüsü, yayımlanmamış, yayınlanmamış, görülmüştür,
# Nearest to edilen: elde, edilmiştir, ile, olarak, sonuçlar, bu, edilmiş, sonuç,
# Nearest to parameters: parameter, parametreleri, investigated, parametrelerin, parametre, table, given, comparison,
# Nearest to thus: have, such, therefore, since, as, to, where, by,
# Nearest to toplumun: topluma, toplumda, toplumsal, değerlerin, kültürün, toplumdaki, birey, toplum,
# Nearest to und: zur, für, zu, eine, zum, aus, auf, über,
# Nearest to kurumu: kurumunun, ankara, basımevi, yayınları, i̇statistik, kültür, sözlüğü, tdk,
# Nearest to kendisine: ettiği, kendisinin, kendisini, ona, etmesi, eder, verdiği, onu,
# Nearest to set: sets, denoted, fuzzy, definition, let, then, called, intersection,
# Nearest to dışı: gibi, dışında, nedeniyle, alınmıştır, bazı, alınmış, dahil, ise,
# Epoch 15/15 Iteration: 327100 Avg. Training loss: 4.0516 0.0429 sec/batch
# Epoch 15/15 Iteration: 327200 Avg. Training loss: 3.9842 0.0383 sec/batch
# Epoch 15/15 Iteration: 327300 Avg. Training loss: 4.0194 0.0383 sec/batch
# Epoch 15/15 Iteration: 327400 Avg. Training loss: 3.8930 0.0384 sec/batch
# Epoch 15/15 Iteration: 327500 Avg. Training loss: 3.7832 0.0384 sec/batch
# Epoch 15/15 Iteration: 327600 Avg. Training loss: 3.9888 0.0385 sec/batch
# Epoch 15/15 Iteration: 327700 Avg. Training loss: 3.9885 0.0386 sec/batch
# Epoch 15/15 Iteration: 327800 Avg. Training loss: 4.0435 0.0385 sec/batch
# Epoch 15/15 Iteration: 327900 Avg. Training loss: 3.9176 0.0386 sec/batch
# Epoch 15/15 Iteration: 328000 Avg. Training loss: 3.9383 0.0388 sec/batch
# Nearest to olduğu: görülmektedir, olarak, söylenebilir, da, bu, ise, bir, ile,
# Nearest to o: m, a, e, g, s, i̇, d, r,
# Nearest to h: m, a, l, g, s, d, c, r,
# Nearest to c: m, s, d, g, a, b, h, and,
# Nearest to sosyal: bilimler, dergisi, üniversitesi, enstitüsü, doktora, tezi, i̇ktisadi, yayınlanmamış,
# Nearest to tarafından: olarak, bu, bir, ve, olan, yılında, da, ayrıca,
# Nearest to yüksek: düşük, lisans, tezi, doktora, yayımlanmamış, enstitüsü, daha, sahip,
# Nearest to edilen: elde, edilmiştir, sonuç, ile, bu, olarak, ve, bir,
# Nearest to parameters: parameter, table, parametreleri, biochemical, investigated, parametre, results, parametrelerin,
# Nearest to thus: since, to, the, which, therefore, have, such, in,
# Nearest to toplumun: topluma, toplumsal, toplumda, birey, önemlidir, bireyin, toplumdaki, toplum,
# Nearest to und: zur, zu, für, eine, aus, auf, zum, zwischen,
# Nearest to kurumu: ankara, kurumunun, basımevi, tdk, yayınları, sözlüğü, çev, tarih,
# Nearest to kendisine: bir, ettiği, kendisini, bunun, yaptığı, olanı, olarak, kendisinin,
# Nearest to set: sets, fuzzy, denoted, let, reasoning, called, every, definition,
# Nearest to dışı: gibi, dahil, alınmış, nedeniyle, da, dışında, içinde, olmayan,
# Epoch 15/15 Iteration: 328100 Avg. Training loss: 3.9360 0.0433 sec/batch
# Epoch 15/15 Iteration: 328200 Avg. Training loss: 4.0934 0.0380 sec/batch
# Epoch 15/15 Iteration: 328300 Avg. Training loss: 4.0783 0.0380 sec/batch
# Epoch 15/15 Iteration: 328400 Avg. Training loss: 4.0165 0.0381 sec/batch
# Epoch 15/15 Iteration: 328500 Avg. Training loss: 3.9742 0.0386 sec/batch
# Epoch 15/15 Iteration: 328600 Avg. Training loss: 4.0400 0.0382 sec/batch
